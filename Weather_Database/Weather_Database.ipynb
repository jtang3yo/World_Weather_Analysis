# %%
import pandas as pd

import numpy as np

# %%
#Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Get the nearest city using the citipy module.
coordinates = list(lat_lngs)
from citipy import citipy 
cities =[] 
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities: 
        cities.append(city)
len(cities)
# Out:
# 763

# %%
#Perform an API call with the OpenWeatherMap.
import requests
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#retrieve data from api call 
from datetime import datetime 
city_data = []
print("Beginning Data Retrieval     ")
print("-----------------------------")
#create counters 
record_count = 1 
set_count = 1 
for i, city in enumerate(cities): 
    if (i % 50 == 0 and i >= 50):
        record_count +=1
        set_count += 1 
    city_url = url + "&q=" + city.replace(" ","+")
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    record_count +=1 
    #try-except block to avoid no results 
    try: 
        city_weather = requests.get(city_url).json()
        #print(city_weather)
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          "Date": city_date})
    except Exception as e:
        print(e)
        print("City not found...skipping")
    
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saint-leu
# Processing Record 2 of Set 1 | rudnogorsk
# Processing Record 3 of Set 1 | sao joao da barra
# Processing Record 4 of Set 1 | verkhoyansk
# Processing Record 5 of Set 1 | bealanana
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | vanimo
# Processing Record 8 of Set 1 | shenjiamen
# Processing Record 9 of Set 1 | aykhal
# Processing Record 10 of Set 1 | camana
# Processing Record 11 of Set 1 | lompoc
# Processing Record 12 of Set 1 | kamenskoye
# 'coord'
# City not found...skipping
# Processing Record 13 of Set 1 | castro
# Processing Record 14 of Set 1 | glendive
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | tabiauea
# 'coord'
# City not found...skipping
# Processing Record 17 of Set 1 | arraial do cabo
# Processing Record 18 of Set 1 | illoqqortoormiut
# 'coord'
# City not found...skipping
# Processing Record 19 of Set 1 | udachnyy
# Processing Record 20 of Set 1 | taolanaro
# 'coord'
# City not found...skipping
# Processing Record 21 of Set 1 | suhut
# Processing Record 22 of Set 1 | dikson
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | samarai
# Processing Record 26 of Set 1 | puerto ayora
# Processing Record 27 of Set 1 | ahipara
# Processing Record 28 of Set 1 | bethel
# Processing Record 29 of Set 1 | talpa
# Processing Record 30 of Set 1 | lorengau
# Processing Record 31 of Set 1 | touros
# Processing Record 32 of Set 1 | xining
# Processing Record 33 of Set 1 | iqaluit
# Processing Record 34 of Set 1 | bubaque
# Processing Record 35 of Set 1 | khasan
# Processing Record 36 of Set 1 | whakatane
# Processing Record 37 of Set 1 | khatanga
# Processing Record 38 of Set 1 | lagos
# Processing Record 39 of Set 1 | ushuaia
# Processing Record 40 of Set 1 | talnakh
# Processing Record 41 of Set 1 | santa cruz
# Processing Record 42 of Set 1 | new norfolk
# Processing Record 43 of Set 1 | ndende
# Processing Record 44 of Set 1 | shingu
# Processing Record 45 of Set 1 | butaritari
# Processing Record 46 of Set 1 | san quintin
# Processing Record 47 of Set 1 | koslan
# Processing Record 48 of Set 1 | palma di montechiaro
# Processing Record 49 of Set 1 | busselton
# Processing Record 50 of Set 1 | punta arenas
# Processing Record 52 of Set 2 | atbasar
# Processing Record 53 of Set 2 | sitka
# Processing Record 54 of Set 2 | dinghai
# Processing Record 55 of Set 2 | bitung
# Processing Record 56 of Set 2 | maceio
# Processing Record 57 of Set 2 | lebu
# Processing Record 58 of Set 2 | kaitangata
# Processing Record 59 of Set 2 | tasiilaq
# Processing Record 60 of Set 2 | bredasdorp
# Processing Record 61 of Set 2 | cape town
# Processing Record 62 of Set 2 | mae sot
# Processing Record 63 of Set 2 | atuona
# Processing Record 64 of Set 2 | yellowknife
# Processing Record 65 of Set 2 | port alfred
# Processing Record 66 of Set 2 | thompson
# Processing Record 67 of Set 2 | harbour breton
# Processing Record 68 of Set 2 | provideniya
# Processing Record 69 of Set 2 | hakodate
# Processing Record 70 of Set 2 | tuktoyaktuk
# Processing Record 71 of Set 2 | kapaa
# Processing Record 72 of Set 2 | surt
# Processing Record 73 of Set 2 | chifeng
# Processing Record 74 of Set 2 | grand gaube
# Processing Record 75 of Set 2 | sisimiut
# Processing Record 76 of Set 2 | san patricio
# Processing Record 77 of Set 2 | bluff
# Processing Record 78 of Set 2 | saleaula
# 'coord'
# City not found...skipping
# Processing Record 79 of Set 2 | hobart
# Processing Record 80 of Set 2 | qaanaaq
# Processing Record 81 of Set 2 | kununurra
# Processing Record 82 of Set 2 | cidreira
# Processing Record 83 of Set 2 | nikolskoye
# Processing Record 84 of Set 2 | paz de ariporo
# 'coord'
# City not found...skipping
# Processing Record 85 of Set 2 | upernavik
# Processing Record 86 of Set 2 | inhambane
# Processing Record 87 of Set 2 | broken hill
# Processing Record 88 of Set 2 | padang
# Processing Record 89 of Set 2 | trelew
# Processing Record 90 of Set 2 | sinnamary
# Processing Record 91 of Set 2 | tahta
# Processing Record 92 of Set 2 | hithadhoo
# Processing Record 93 of Set 2 | cabo san lucas
# Processing Record 94 of Set 2 | balkanabat
# Processing Record 95 of Set 2 | kavieng
# Processing Record 96 of Set 2 | east london
# Processing Record 97 of Set 2 | carnarvon
# Processing Record 98 of Set 2 | ambilobe
# Processing Record 99 of Set 2 | vestmannaeyjar
# Processing Record 100 of Set 2 | elban
# Processing Record 101 of Set 2 | port moresby
# Processing Record 103 of Set 3 | geraldton
# Processing Record 104 of Set 3 | tumannyy
# 'coord'
# City not found...skipping
# Processing Record 105 of Set 3 | san cristobal
# Processing Record 106 of Set 3 | vaini
# Processing Record 107 of Set 3 | tura
# Processing Record 108 of Set 3 | sfantu gheorghe
# Processing Record 109 of Set 3 | bambous virieux
# Processing Record 110 of Set 3 | vlagtwedde
# Processing Record 111 of Set 3 | mar del plata
# Processing Record 112 of Set 3 | chuy
# Processing Record 113 of Set 3 | roseburg
# Processing Record 114 of Set 3 | margate
# Processing Record 115 of Set 3 | galveston
# Processing Record 116 of Set 3 | cherskiy
# Processing Record 117 of Set 3 | fevralsk
# 'coord'
# City not found...skipping
# Processing Record 118 of Set 3 | urusha
# Processing Record 119 of Set 3 | vardo
# Processing Record 120 of Set 3 | tyukhtet
# Processing Record 121 of Set 3 | khilok
# Processing Record 122 of Set 3 | saint george
# Processing Record 123 of Set 3 | omboue
# Processing Record 124 of Set 3 | nguiu
# 'coord'
# City not found...skipping
# Processing Record 125 of Set 3 | aberfeldy
# Processing Record 126 of Set 3 | zhigalovo
# Processing Record 127 of Set 3 | ondorhaan
# 'coord'
# City not found...skipping
# Processing Record 128 of Set 3 | ishigaki
# Processing Record 129 of Set 3 | pisco
# Processing Record 130 of Set 3 | opuwo
# Processing Record 131 of Set 3 | ribeira grande
# Processing Record 132 of Set 3 | kuche
# 'coord'
# City not found...skipping
# Processing Record 133 of Set 3 | torbay
# Processing Record 134 of Set 3 | dunedin
# Processing Record 135 of Set 3 | leshukonskoye
# Processing Record 136 of Set 3 | kavaratti
# Processing Record 137 of Set 3 | bur gabo
# 'coord'
# City not found...skipping
# Processing Record 138 of Set 3 | jamestown
# Processing Record 139 of Set 3 | ellensburg
# Processing Record 140 of Set 3 | bengkulu
# Processing Record 141 of Set 3 | grand river south east
# 'coord'
# City not found...skipping
# Processing Record 142 of Set 3 | antigonish
# Processing Record 143 of Set 3 | orkney
# Processing Record 144 of Set 3 | zlatoust
# Processing Record 145 of Set 3 | sindor
# Processing Record 146 of Set 3 | ambon
# Processing Record 147 of Set 3 | gasa
# Processing Record 148 of Set 3 | bahar
# Processing Record 149 of Set 3 | fairbanks
# Processing Record 150 of Set 3 | turek
# Processing Record 151 of Set 3 | denpasar
# Processing Record 152 of Set 3 | maniitsoq
# Processing Record 154 of Set 4 | lewisporte
# Processing Record 155 of Set 4 | te anau
# Processing Record 156 of Set 4 | hay river
# Processing Record 157 of Set 4 | bambari
# Processing Record 158 of Set 4 | muslyumovo
# Processing Record 159 of Set 4 | christchurch
# Processing Record 160 of Set 4 | woodward
# Processing Record 161 of Set 4 | grand centre
# 'coord'
# City not found...skipping
# Processing Record 162 of Set 4 | kodiak
# Processing Record 163 of Set 4 | omaruru
# Processing Record 164 of Set 4 | karratha
# Processing Record 165 of Set 4 | avarua
# Processing Record 166 of Set 4 | nauta
# Processing Record 167 of Set 4 | fortuna
# Processing Record 168 of Set 4 | nizhneyansk
# 'coord'
# City not found...skipping
# Processing Record 169 of Set 4 | hilo
# Processing Record 170 of Set 4 | georgetown
# Processing Record 171 of Set 4 | kano
# Processing Record 172 of Set 4 | chernyshevskiy
# Processing Record 173 of Set 4 | mahebourg
# Processing Record 174 of Set 4 | agirish
# Processing Record 175 of Set 4 | cullinan
# Processing Record 176 of Set 4 | tres arroyos
# Processing Record 177 of Set 4 | saldanha
# Processing Record 178 of Set 4 | bilokurakyne
# Processing Record 179 of Set 4 | saint-augustin
# Processing Record 180 of Set 4 | tubruq
# 'coord'
# City not found...skipping
# Processing Record 181 of Set 4 | irece
# Processing Record 182 of Set 4 | walvis bay
# Processing Record 183 of Set 4 | adrar
# Processing Record 184 of Set 4 | port lincoln
# Processing Record 185 of Set 4 | saskylakh
# Processing Record 186 of Set 4 | uk
# 'coord'
# City not found...skipping
# Processing Record 187 of Set 4 | kemise
# Processing Record 188 of Set 4 | simi
# Processing Record 189 of Set 4 | mendahara
# 'coord'
# City not found...skipping
# Processing Record 190 of Set 4 | qianan
# Processing Record 191 of Set 4 | los llanos de aridane
# Processing Record 192 of Set 4 | carballo
# Processing Record 193 of Set 4 | svetlyy
# Processing Record 194 of Set 4 | ust-kuyga
# Processing Record 195 of Set 4 | mitsamiouli
# Processing Record 196 of Set 4 | avera
# Processing Record 197 of Set 4 | muravlenko
# Processing Record 198 of Set 4 | am timan
# Processing Record 199 of Set 4 | lahaina
# Processing Record 200 of Set 4 | shimanovsk
# Processing Record 201 of Set 4 | vila franca do campo
# Processing Record 202 of Set 4 | manzhouli
# Processing Record 203 of Set 4 | alofi
# Processing Record 205 of Set 5 | rawannawi
# 'coord'
# City not found...skipping
# Processing Record 206 of Set 5 | sao francisco
# Processing Record 207 of Set 5 | cap malheureux
# Processing Record 208 of Set 5 | gobabis
# Processing Record 209 of Set 5 | barrow
# Processing Record 210 of Set 5 | keti bandar
# Processing Record 211 of Set 5 | kokoda
# Processing Record 212 of Set 5 | portland
# Processing Record 213 of Set 5 | westport
# Processing Record 214 of Set 5 | ostersund
# Processing Record 215 of Set 5 | grants
# Processing Record 216 of Set 5 | gat
# Processing Record 217 of Set 5 | comodoro rivadavia
# Processing Record 218 of Set 5 | samusu
# 'coord'
# City not found...skipping
# Processing Record 219 of Set 5 | maidens
# Processing Record 220 of Set 5 | raudeberg
# Processing Record 221 of Set 5 | bilibino
# Processing Record 222 of Set 5 | saint-philippe
# Processing Record 223 of Set 5 | oshnaviyeh
# Processing Record 224 of Set 5 | fort nelson
# Processing Record 225 of Set 5 | waingapu
# Processing Record 226 of Set 5 | paraiso
# Processing Record 227 of Set 5 | canico
# Processing Record 228 of Set 5 | asfi
# Processing Record 229 of Set 5 | labuhan
# Processing Record 230 of Set 5 | hasaki
# Processing Record 231 of Set 5 | tessalit
# Processing Record 232 of Set 5 | belushya guba
# 'coord'
# City not found...skipping
# Processing Record 233 of Set 5 | vaxjo
# Processing Record 234 of Set 5 | kushima
# Processing Record 235 of Set 5 | itum-kale
# Processing Record 236 of Set 5 | quatre cocos
# Processing Record 237 of Set 5 | marystown
# Processing Record 238 of Set 5 | salalah
# Processing Record 239 of Set 5 | chokurdakh
# Processing Record 240 of Set 5 | vyshchetarasivka
# Processing Record 241 of Set 5 | kupang
# Processing Record 242 of Set 5 | shimoda
# Processing Record 243 of Set 5 | barentsburg
# 'coord'
# City not found...skipping
# Processing Record 244 of Set 5 | magadan
# Processing Record 245 of Set 5 | port elizabeth
# Processing Record 246 of Set 5 | karlskrona
# Processing Record 247 of Set 5 | northam
# Processing Record 248 of Set 5 | san policarpo
# Processing Record 249 of Set 5 | bama
# Processing Record 250 of Set 5 | nedryhayliv
# Processing Record 251 of Set 5 | olinda
# Processing Record 252 of Set 5 | victoria
# Processing Record 253 of Set 5 | strezhevoy
# Processing Record 254 of Set 5 | sibolga
# Processing Record 256 of Set 6 | manosque
# Processing Record 257 of Set 6 | louisbourg
# 'coord'
# City not found...skipping
# Processing Record 258 of Set 6 | mount isa
# Processing Record 259 of Set 6 | asau
# Processing Record 260 of Set 6 | ponta do sol
# Processing Record 261 of Set 6 | nam tha
# 'coord'
# City not found...skipping
# Processing Record 262 of Set 6 | ryotsu
# Processing Record 263 of Set 6 | pimentel
# Processing Record 264 of Set 6 | dingolfing
# Processing Record 265 of Set 6 | poum
# Processing Record 266 of Set 6 | praia da vitoria
# Processing Record 267 of Set 6 | shaowu
# Processing Record 268 of Set 6 | talesh
# 'coord'
# City not found...skipping
# Processing Record 269 of Set 6 | trat
# Processing Record 270 of Set 6 | san jose
# Processing Record 271 of Set 6 | tilichiki
# Processing Record 272 of Set 6 | port hardy
# Processing Record 273 of Set 6 | bayangol
# Processing Record 274 of Set 6 | luba
# Processing Record 275 of Set 6 | mayo
# Processing Record 276 of Set 6 | nha trang
# Processing Record 277 of Set 6 | coquimbo
# Processing Record 278 of Set 6 | katsuura
# Processing Record 279 of Set 6 | kenai
# Processing Record 280 of Set 6 | charters towers
# Processing Record 281 of Set 6 | aklavik
# Processing Record 282 of Set 6 | murray bridge
# Processing Record 283 of Set 6 | hovd
# Processing Record 284 of Set 6 | hambantota
# Processing Record 285 of Set 6 | srednekolymsk
# Processing Record 286 of Set 6 | marawi
# Processing Record 287 of Set 6 | dingle
# Processing Record 288 of Set 6 | bershet
# Processing Record 289 of Set 6 | umm lajj
# Processing Record 290 of Set 6 | port-gentil
# Processing Record 291 of Set 6 | minchinabad
# Processing Record 292 of Set 6 | sioux lookout
# Processing Record 293 of Set 6 | oussouye
# Processing Record 294 of Set 6 | chino valley
# Processing Record 295 of Set 6 | lavrentiya
# Processing Record 296 of Set 6 | tashara
# Processing Record 297 of Set 6 | klaksvik
# Processing Record 298 of Set 6 | naze
# Processing Record 299 of Set 6 | maningrida
# Processing Record 300 of Set 6 | narsaq
# Processing Record 301 of Set 6 | siguiri
# Processing Record 302 of Set 6 | sal rei
# Processing Record 303 of Set 6 | armacao dos buzios
# 'coord'
# City not found...skipping
# Processing Record 304 of Set 6 | codrington
# Processing Record 305 of Set 6 | sorong
# Processing Record 307 of Set 7 | kraslava
# Processing Record 308 of Set 7 | hofn
# Processing Record 309 of Set 7 | buraydah
# Processing Record 310 of Set 7 | arman
# Processing Record 311 of Set 7 | jiddah
# 'coord'
# City not found...skipping
# Processing Record 312 of Set 7 | osorno
# Processing Record 313 of Set 7 | kalmunai
# Processing Record 314 of Set 7 | gravdal
# Processing Record 315 of Set 7 | labuan
# Processing Record 316 of Set 7 | lima
# Processing Record 317 of Set 7 | mao
# Processing Record 318 of Set 7 | faya
# Processing Record 319 of Set 7 | vostok
# Processing Record 320 of Set 7 | sohag
# Processing Record 321 of Set 7 | kambove
# Processing Record 322 of Set 7 | burley
# Processing Record 323 of Set 7 | ruteng
# Processing Record 324 of Set 7 | dauriya
# Processing Record 325 of Set 7 | sakakah
# Processing Record 326 of Set 7 | smiltene
# Processing Record 327 of Set 7 | haines junction
# Processing Record 328 of Set 7 | tiksi
# Processing Record 329 of Set 7 | lichinga
# Processing Record 330 of Set 7 | killam
# Processing Record 331 of Set 7 | rovinj
# Processing Record 332 of Set 7 | tuatapere
# Processing Record 333 of Set 7 | damghan
# Processing Record 334 of Set 7 | sentyabrskiy
# 'coord'
# City not found...skipping
# Processing Record 335 of Set 7 | kigoma
# Processing Record 336 of Set 7 | lagunas
# Processing Record 337 of Set 7 | souillac
# Processing Record 338 of Set 7 | port hawkesbury
# Processing Record 339 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 340 of Set 7 | balkhash
# Processing Record 341 of Set 7 | bundaberg
# Processing Record 342 of Set 7 | san jeronimo
# Processing Record 343 of Set 7 | batagay-alyta
# Processing Record 344 of Set 7 | odweyne
# Processing Record 345 of Set 7 | luderitz
# Processing Record 346 of Set 7 | bhikhi
# Processing Record 347 of Set 7 | port blair
# Processing Record 348 of Set 7 | calama
# Processing Record 349 of Set 7 | norman wells
# Processing Record 350 of Set 7 | najran
# Processing Record 351 of Set 7 | lubao
# Processing Record 352 of Set 7 | beaverlodge
# Processing Record 353 of Set 7 | hami
# Processing Record 354 of Set 7 | muana
# Processing Record 355 of Set 7 | rosarito
# Processing Record 356 of Set 7 | attawapiskat
# 'coord'
# City not found...skipping
# Processing Record 358 of Set 8 | igarka
# Processing Record 359 of Set 8 | juba
# Processing Record 360 of Set 8 | guerrero negro
# Processing Record 361 of Set 8 | altay
# Processing Record 362 of Set 8 | la cruz
# Processing Record 363 of Set 8 | ugoofaaru
# Processing Record 364 of Set 8 | alice springs
# Processing Record 365 of Set 8 | zhigansk
# Processing Record 366 of Set 8 | sume
# Processing Record 367 of Set 8 | nemuro
# Processing Record 368 of Set 8 | bayji
# Processing Record 369 of Set 8 | koutiala
# Processing Record 370 of Set 8 | kuopio
# Processing Record 371 of Set 8 | clyde river
# Processing Record 372 of Set 8 | mys shmidta
# 'coord'
# City not found...skipping
# Processing Record 373 of Set 8 | zapolyarnyy
# Processing Record 374 of Set 8 | namibe
# Processing Record 375 of Set 8 | jiaohe
# Processing Record 376 of Set 8 | sao caetano de odivelas
# Processing Record 377 of Set 8 | lagoa
# Processing Record 378 of Set 8 | kamaishi
# Processing Record 379 of Set 8 | saint-georges
# Processing Record 380 of Set 8 | mackay
# Processing Record 381 of Set 8 | itamaraca
# Processing Record 382 of Set 8 | husavik
# Processing Record 383 of Set 8 | roald
# Processing Record 384 of Set 8 | cayenne
# Processing Record 385 of Set 8 | egvekinot
# Processing Record 386 of Set 8 | mataram
# Processing Record 387 of Set 8 | nelson bay
# Processing Record 388 of Set 8 | hualmay
# Processing Record 389 of Set 8 | den helder
# Processing Record 390 of Set 8 | esperance
# Processing Record 391 of Set 8 | bonthe
# Processing Record 392 of Set 8 | beira
# Processing Record 393 of Set 8 | owando
# Processing Record 394 of Set 8 | umzimvubu
# 'coord'
# City not found...skipping
# Processing Record 395 of Set 8 | sao filipe
# Processing Record 396 of Set 8 | abidjan
# Processing Record 397 of Set 8 | schoneiche
# Processing Record 398 of Set 8 | caiaponia
# Processing Record 399 of Set 8 | pangnirtung
# Processing Record 400 of Set 8 | berlevag
# Processing Record 401 of Set 8 | roma
# Processing Record 402 of Set 8 | dourdan
# Processing Record 403 of Set 8 | hegra
# Processing Record 404 of Set 8 | mokhotlong
# Processing Record 405 of Set 8 | luwuk
# Processing Record 406 of Set 8 | almaznyy
# Processing Record 407 of Set 8 | faanui
# Processing Record 409 of Set 9 | yabrud
# Processing Record 410 of Set 9 | mormugao
# Processing Record 411 of Set 9 | mackenzie
# Processing Record 412 of Set 9 | severo-kurilsk
# Processing Record 413 of Set 9 | de-kastri
# Processing Record 414 of Set 9 | piacabucu
# Processing Record 415 of Set 9 | lasa
# Processing Record 416 of Set 9 | road town
# Processing Record 417 of Set 9 | marcona
# 'coord'
# City not found...skipping
# Processing Record 418 of Set 9 | gallup
# Processing Record 419 of Set 9 | bud
# Processing Record 420 of Set 9 | nizhniy kuranakh
# Processing Record 421 of Set 9 | airai
# Processing Record 422 of Set 9 | ixtapa
# Processing Record 423 of Set 9 | manicore
# Processing Record 424 of Set 9 | halalo
# 'coord'
# City not found...skipping
# Processing Record 425 of Set 9 | makakilo city
# Processing Record 426 of Set 9 | belmonte
# Processing Record 427 of Set 9 | rathdrum
# Processing Record 428 of Set 9 | yangjiang
# Processing Record 429 of Set 9 | temaraia
# 'coord'
# City not found...skipping
# Processing Record 430 of Set 9 | svetlogorsk
# Processing Record 431 of Set 9 | seondha
# Processing Record 432 of Set 9 | yirol
# 'coord'
# City not found...skipping
# Processing Record 433 of Set 9 | victor harbor
# Processing Record 434 of Set 9 | sinnar
# Processing Record 435 of Set 9 | rawson
# Processing Record 436 of Set 9 | college
# Processing Record 437 of Set 9 | lata
# Processing Record 438 of Set 9 | mount gambier
# Processing Record 439 of Set 9 | naftah
# 'coord'
# City not found...skipping
# Processing Record 440 of Set 9 | aksarka
# Processing Record 441 of Set 9 | uyo
# Processing Record 442 of Set 9 | tamandare
# Processing Record 443 of Set 9 | chamrajnagar
# Processing Record 444 of Set 9 | pafos
# Processing Record 445 of Set 9 | krasnoyarskiy
# Processing Record 446 of Set 9 | araceli
# Processing Record 447 of Set 9 | yining
# Processing Record 448 of Set 9 | shepsi
# Processing Record 449 of Set 9 | healdsburg
# Processing Record 450 of Set 9 | aldan
# Processing Record 451 of Set 9 | saint-pierre
# Processing Record 452 of Set 9 | tunduma
# Processing Record 453 of Set 9 | jaroslaw
# Processing Record 454 of Set 9 | tarudant
# 'coord'
# City not found...skipping
# Processing Record 455 of Set 9 | santa cruz cabralia
# Processing Record 456 of Set 9 | nalut
# Processing Record 457 of Set 9 | urengoy
# Processing Record 458 of Set 9 | ostrovnoy
# Processing Record 460 of Set 10 | erzurum
# Processing Record 461 of Set 10 | gresham
# Processing Record 462 of Set 10 | talara
# Processing Record 463 of Set 10 | meyungs
# 'coord'
# City not found...skipping
# Processing Record 464 of Set 10 | xuddur
# Processing Record 465 of Set 10 | waddan
# Processing Record 466 of Set 10 | aflu
# 'coord'
# City not found...skipping
# Processing Record 467 of Set 10 | bowen
# Processing Record 468 of Set 10 | new britain
# Processing Record 469 of Set 10 | mendi
# Processing Record 470 of Set 10 | sembakung
# Processing Record 471 of Set 10 | evensk
# Processing Record 472 of Set 10 | batticaloa
# Processing Record 473 of Set 10 | osuna
# Processing Record 474 of Set 10 | cockburn town
# Processing Record 475 of Set 10 | ambunti
# Processing Record 476 of Set 10 | vaitupu
# 'coord'
# City not found...skipping
# Processing Record 477 of Set 10 | manjakandriana
# Processing Record 478 of Set 10 | nome
# Processing Record 479 of Set 10 | mykhaylivka
# Processing Record 480 of Set 10 | burkhala
# 'coord'
# City not found...skipping
# Processing Record 481 of Set 10 | zolotinka
# 'coord'
# City not found...skipping
# Processing Record 482 of Set 10 | palmer
# Processing Record 483 of Set 10 | asayita
# 'coord'
# City not found...skipping
# Processing Record 484 of Set 10 | trairi
# Processing Record 485 of Set 10 | soeng sang
# Processing Record 486 of Set 10 | mosna
# Processing Record 487 of Set 10 | angoram
# Processing Record 488 of Set 10 | broome
# Processing Record 489 of Set 10 | palauig
# Processing Record 490 of Set 10 | puerto lopez
# Processing Record 491 of Set 10 | taperoa
# Processing Record 492 of Set 10 | sechura
# Processing Record 493 of Set 10 | palabuhanratu
# 'coord'
# City not found...skipping
# Processing Record 494 of Set 10 | nanortalik
# Processing Record 495 of Set 10 | kysyl-syr
# Processing Record 496 of Set 10 | tazovskiy
# Processing Record 497 of Set 10 | te horo
# Processing Record 498 of Set 10 | samalaeulu
# 'coord'
# City not found...skipping
# Processing Record 499 of Set 10 | pingliang
# Processing Record 500 of Set 10 | tiznit
# Processing Record 501 of Set 10 | tsihombe
# 'coord'
# City not found...skipping
# Processing Record 502 of Set 10 | longyearbyen
# Processing Record 503 of Set 10 | bhuj
# Processing Record 504 of Set 10 | ilulissat
# Processing Record 505 of Set 10 | timmins
# Processing Record 506 of Set 10 | kungurtug
# Processing Record 507 of Set 10 | mangan
# Processing Record 508 of Set 10 | aguas belas
# Processing Record 509 of Set 10 | boralday
# Processing Record 511 of Set 11 | jalu
# Processing Record 512 of Set 11 | sembe
# Processing Record 513 of Set 11 | cacule
# Processing Record 514 of Set 11 | vao
# Processing Record 515 of Set 11 | oistins
# Processing Record 516 of Set 11 | snezhnogorsk
# Processing Record 517 of Set 11 | taguatinga
# Processing Record 518 of Set 11 | nabire
# Processing Record 519 of Set 11 | nishihara
# Processing Record 520 of Set 11 | morwell
# Processing Record 521 of Set 11 | pacific grove
# Processing Record 522 of Set 11 | ossora
# Processing Record 523 of Set 11 | bilma
# Processing Record 524 of Set 11 | the valley
# Processing Record 525 of Set 11 | haapiti
# Processing Record 526 of Set 11 | katangli
# Processing Record 527 of Set 11 | kunya
# Processing Record 528 of Set 11 | dolinsk
# Processing Record 529 of Set 11 | palasa
# Processing Record 530 of Set 11 | krasnoselkup
# Processing Record 531 of Set 11 | malartic
# Processing Record 532 of Set 11 | morondava
# Processing Record 533 of Set 11 | dunyapur
# Processing Record 534 of Set 11 | rungata
# 'coord'
# City not found...skipping
# Processing Record 535 of Set 11 | douentza
# Processing Record 536 of Set 11 | japura
# Processing Record 537 of Set 11 | asheboro
# Processing Record 538 of Set 11 | taoudenni
# Processing Record 539 of Set 11 | yuncheng
# Processing Record 540 of Set 11 | awjilah
# Processing Record 541 of Set 11 | kampot
# Processing Record 542 of Set 11 | atar
# Processing Record 543 of Set 11 | antalaha
# Processing Record 544 of Set 11 | nyurba
# Processing Record 545 of Set 11 | bathsheba
# Processing Record 546 of Set 11 | sirsi
# Processing Record 547 of Set 11 | laguna
# Processing Record 548 of Set 11 | tabou
# Processing Record 549 of Set 11 | tautira
# Processing Record 550 of Set 11 | karpathos
# Processing Record 551 of Set 11 | opobo
# 'coord'
# City not found...skipping
# Processing Record 552 of Set 11 | belaya gora
# Processing Record 553 of Set 11 | tougan
# Processing Record 554 of Set 11 | sambava
# Processing Record 555 of Set 11 | formosa do rio preto
# Processing Record 556 of Set 11 | ternate
# Processing Record 557 of Set 11 | seoul
# Processing Record 558 of Set 11 | sabang
# Processing Record 559 of Set 11 | baculin
# Processing Record 560 of Set 11 | sorvag
# 'coord'
# City not found...skipping
# Processing Record 562 of Set 12 | ijaki
# 'coord'
# City not found...skipping
# Processing Record 563 of Set 12 | ambatondrazaka
# Processing Record 564 of Set 12 | bacuit
# 'coord'
# City not found...skipping
# Processing Record 565 of Set 12 | luorong
# Processing Record 566 of Set 12 | tsiroanomandidy
# Processing Record 567 of Set 12 | mezen
# Processing Record 568 of Set 12 | nipawin
# Processing Record 569 of Set 12 | jardim
# Processing Record 570 of Set 12 | lakeway
# Processing Record 571 of Set 12 | kitami
# Processing Record 572 of Set 12 | buzmeyin
# Processing Record 573 of Set 12 | ruatoria
# 'coord'
# City not found...skipping
# Processing Record 574 of Set 12 | north platte
# Processing Record 575 of Set 12 | san vicente de chucuri
# Processing Record 576 of Set 12 | sept-iles
# Processing Record 577 of Set 12 | grindavik
# Processing Record 578 of Set 12 | vila velha
# Processing Record 579 of Set 12 | muros
# Processing Record 580 of Set 12 | ozernovskiy
# Processing Record 581 of Set 12 | quang ngai
# Processing Record 582 of Set 12 | anchorage
# Processing Record 583 of Set 12 | cururupu
# Processing Record 584 of Set 12 | menomonie
# Processing Record 585 of Set 12 | kasongo-lunda
# Processing Record 586 of Set 12 | wahran
# 'coord'
# City not found...skipping
# Processing Record 587 of Set 12 | yarmouth
# Processing Record 588 of Set 12 | half moon bay
# Processing Record 589 of Set 12 | thinadhoo
# Processing Record 590 of Set 12 | maua
# Processing Record 591 of Set 12 | olden
# Processing Record 592 of Set 12 | normandin
# Processing Record 593 of Set 12 | pervomayskoye
# Processing Record 594 of Set 12 | chagoda
# Processing Record 595 of Set 12 | mokhsogollokh
# Processing Record 596 of Set 12 | natal
# Processing Record 597 of Set 12 | plettenberg bay
# Processing Record 598 of Set 12 | mizan teferi
# Processing Record 599 of Set 12 | yasnaya polyana
# Processing Record 600 of Set 12 | la primavera
# Processing Record 601 of Set 12 | bolgar
# Processing Record 602 of Set 12 | hamilton
# Processing Record 603 of Set 12 | edd
# Processing Record 604 of Set 12 | pitangueiras
# Processing Record 605 of Set 12 | tazmalt
# Processing Record 606 of Set 12 | alta floresta
# Processing Record 607 of Set 12 | babanusah
# 'coord'
# City not found...skipping
# Processing Record 608 of Set 12 | shorewood
# Processing Record 609 of Set 12 | tobane
# Processing Record 610 of Set 12 | lichtenburg
# Processing Record 611 of Set 12 | nicoya
# Processing Record 613 of Set 13 | eirunepe
# Processing Record 614 of Set 13 | manokwari
# Processing Record 615 of Set 13 | korla
# Processing Record 616 of Set 13 | tumut
# Processing Record 617 of Set 13 | ferrenafe
# Processing Record 618 of Set 13 | severo-yeniseyskiy
# Processing Record 619 of Set 13 | eureka
# Processing Record 620 of Set 13 | toliary
# 'coord'
# City not found...skipping
# Processing Record 621 of Set 13 | boca do acre
# Processing Record 622 of Set 13 | kamina
# Processing Record 623 of Set 13 | mayma
# Processing Record 624 of Set 13 | viligili
# 'coord'
# City not found...skipping
# Processing Record 625 of Set 13 | turbat
# Processing Record 626 of Set 13 | barcelos
# Processing Record 627 of Set 13 | rio gallegos
# Processing Record 628 of Set 13 | mahaicony
# 'coord'
# City not found...skipping
# Processing Record 629 of Set 13 | san vicente
# Processing Record 630 of Set 13 | imbituba
# Processing Record 631 of Set 13 | dicabisagan
# Processing Record 632 of Set 13 | cuamba
# Processing Record 633 of Set 13 | namatanai
# Processing Record 634 of Set 13 | podgornoye
# Processing Record 635 of Set 13 | yulara
# Processing Record 636 of Set 13 | rocha
# Processing Record 637 of Set 13 | rawicz
# Processing Record 638 of Set 13 | acuna
# 'coord'
# City not found...skipping
# Processing Record 639 of Set 13 | hobyo
# Processing Record 640 of Set 13 | honningsvag
# Processing Record 641 of Set 13 | mizdah
# Processing Record 642 of Set 13 | baykit
# Processing Record 643 of Set 13 | ilheus
# Processing Record 644 of Set 13 | leh
# Processing Record 645 of Set 13 | ambanja
# Processing Record 646 of Set 13 | koungheul
# Processing Record 647 of Set 13 | corumba
# Processing Record 648 of Set 13 | bridlington
# Processing Record 649 of Set 13 | clarence town
# Processing Record 650 of Set 13 | conakry
# Processing Record 651 of Set 13 | duluth
# Processing Record 652 of Set 13 | launceston
# Processing Record 653 of Set 13 | pedernales
# Processing Record 654 of Set 13 | dongsheng
# Processing Record 655 of Set 13 | warqla
# 'coord'
# City not found...skipping
# Processing Record 656 of Set 13 | state college
# Processing Record 657 of Set 13 | pevek
# Processing Record 658 of Set 13 | makat
# Processing Record 659 of Set 13 | carmaux
# Processing Record 660 of Set 13 | solnechnyy
# Processing Record 661 of Set 13 | amderma
# 'coord'
# City not found...skipping
# Processing Record 662 of Set 13 | junction city
# Processing Record 664 of Set 14 | abu jubayhah
# 'coord'
# City not found...skipping
# Processing Record 665 of Set 14 | emerald
# Processing Record 666 of Set 14 | norfolk
# Processing Record 667 of Set 14 | maesteg
# Processing Record 668 of Set 14 | topolobampo
# Processing Record 669 of Set 14 | tutoia
# Processing Record 670 of Set 14 | priiskovyy
# Processing Record 671 of Set 14 | puerto carreno
# Processing Record 672 of Set 14 | kamenka
# Processing Record 673 of Set 14 | lugovskiy
# 'coord'
# City not found...skipping
# Processing Record 674 of Set 14 | rock springs
# Processing Record 675 of Set 14 | sorland
# Processing Record 676 of Set 14 | olovyannaya
# Processing Record 677 of Set 14 | shakawe
# Processing Record 678 of Set 14 | maldonado
# Processing Record 679 of Set 14 | las choapas
# Processing Record 680 of Set 14 | khash
# Processing Record 681 of Set 14 | altagracia de orituco
# Processing Record 682 of Set 14 | prince rupert
# Processing Record 683 of Set 14 | kearney
# Processing Record 684 of Set 14 | castelo do piaui
# Processing Record 685 of Set 14 | kapuskasing
# Processing Record 686 of Set 14 | leningradskiy
# Processing Record 687 of Set 14 | kushiro
# Processing Record 688 of Set 14 | elk city
# Processing Record 689 of Set 14 | jizan
# Processing Record 690 of Set 14 | visby
# Processing Record 691 of Set 14 | blagodatnoye
# Processing Record 692 of Set 14 | muisne
# Processing Record 693 of Set 14 | langfang
# Processing Record 694 of Set 14 | shirgaon
# Processing Record 695 of Set 14 | ketchikan
# Processing Record 696 of Set 14 | kothapet
# Processing Record 697 of Set 14 | sokolow podlaski
# Processing Record 698 of Set 14 | fillmore
# Processing Record 699 of Set 14 | baraboo
# Processing Record 700 of Set 14 | honiara
# Processing Record 701 of Set 14 | shubarkuduk
# Processing Record 702 of Set 14 | ayagoz
# Processing Record 703 of Set 14 | kanigoro
# Processing Record 704 of Set 14 | tianpeng
# Processing Record 705 of Set 14 | patea
# Processing Record 706 of Set 14 | vidim
# Processing Record 707 of Set 14 | buala
# Processing Record 708 of Set 14 | makubetsu
# Processing Record 709 of Set 14 | huilong
# Processing Record 710 of Set 14 | saint pete beach
# Processing Record 711 of Set 14 | praia
# Processing Record 712 of Set 14 | canon city
# Processing Record 713 of Set 14 | baoqing
# Processing Record 715 of Set 15 | celestun
# Processing Record 716 of Set 15 | ippy
# Processing Record 717 of Set 15 | san jose pinula
# Processing Record 718 of Set 15 | kibondo
# Processing Record 719 of Set 15 | vila
# Processing Record 720 of Set 15 | sao felix do xingu
# Processing Record 721 of Set 15 | vitim
# Processing Record 722 of Set 15 | librazhd
# Processing Record 723 of Set 15 | kirando
# Processing Record 724 of Set 15 | kloulklubed
# Processing Record 725 of Set 15 | glinka
# Processing Record 726 of Set 15 | manica
# Processing Record 727 of Set 15 | maltahohe
# Processing Record 728 of Set 15 | cabinda
# Processing Record 729 of Set 15 | uwayl
# 'coord'
# City not found...skipping
# Processing Record 730 of Set 15 | port hedland
# Processing Record 731 of Set 15 | beringovskiy
# Processing Record 732 of Set 15 | barra do bugres
# Processing Record 733 of Set 15 | taltal
# Processing Record 734 of Set 15 | el campo
# Processing Record 735 of Set 15 | belawan
# Processing Record 736 of Set 15 | koumac
# Processing Record 737 of Set 15 | havre-saint-pierre
# Processing Record 738 of Set 15 | lethem
# Processing Record 739 of Set 15 | beni mazar
# Processing Record 740 of Set 15 | candawaga
# 'coord'
# City not found...skipping
# Processing Record 741 of Set 15 | alyangula
# Processing Record 742 of Set 15 | port macquarie
# Processing Record 743 of Set 15 | kazanskoye
# Processing Record 744 of Set 15 | kazalinsk
# 'coord'
# City not found...skipping
# Processing Record 745 of Set 15 | moose factory
# Processing Record 746 of Set 15 | sisophon
# Processing Record 747 of Set 15 | dwarka
# Processing Record 748 of Set 15 | kruisfontein
# Processing Record 749 of Set 15 | saravan
# Processing Record 750 of Set 15 | murbad
# Processing Record 751 of Set 15 | buzoesti
# Processing Record 752 of Set 15 | nuuk
# Processing Record 753 of Set 15 | tubuala
# Processing Record 754 of Set 15 | lewistown
# Processing Record 755 of Set 15 | zavyalovo
# Processing Record 756 of Set 15 | oktyabrskoye
# Processing Record 757 of Set 15 | yar-sale
# Processing Record 758 of Set 15 | nagua
# Processing Record 759 of Set 15 | santander
# Processing Record 760 of Set 15 | carahue
# Processing Record 761 of Set 15 | long
# Processing Record 762 of Set 15 | monterey
# Processing Record 763 of Set 15 | yakovlevskoye
# Processing Record 764 of Set 15 | flin flon
# Processing Record 766 of Set 16 | edson
# Processing Record 767 of Set 16 | ingham
# Processing Record 768 of Set 16 | adamovka
# Processing Record 769 of Set 16 | basco
# Processing Record 770 of Set 16 | dali
# Processing Record 771 of Set 16 | chicama
# Processing Record 772 of Set 16 | chegdomyn
# Processing Record 773 of Set 16 | goderich
# Processing Record 774 of Set 16 | liminangcong
# 'coord'
# City not found...skipping
# Processing Record 775 of Set 16 | olga
# Processing Record 776 of Set 16 | longlac
# 'coord'
# City not found...skipping
# Processing Record 777 of Set 16 | chokwe
# Processing Record 778 of Set 16 | agstafa
# 'coord'
# City not found...skipping
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Saint-Leu -21.1500   55.2833     70.63        68          30
# 1           Rudnogorsk  57.2639  103.7519     38.50        41          63
# 2    Sao Joao Da Barra -21.6403  -41.0511     73.09        87           7
# 3          Verkhoyansk  67.5447  133.3850     38.30        54          23
# 4            Bealanana -14.5500   48.7333     54.00        96          64
# ..                 ...      ...       ...       ...       ...         ...
# 690            Chicama  -7.8447  -79.1469     63.14        77          29
# 691          Chegdomyn  51.1167  133.0167     69.37        67          56
# 692           Goderich  43.7501  -81.7165     68.85        69         100
# 693               Olga  43.7444  135.2892     55.65        86         100
# 694             Chokwe -24.5333   32.9833     71.74        70          80
#
#      Wind Speed Country Current Description                 Date
# 0         14.25      RE    scattered clouds  2021-05-21 23:05:46
# 1          2.26      RU       broken clouds  2021-05-21 23:05:46
# 2          8.99      BR           clear sky  2021-05-21 23:04:47
# 3          7.65      RU          few clouds  2021-05-21 23:05:46
# 4          3.71      MG       broken clouds  2021-05-21 23:05:47
# ..          ...     ...                 ...                  ...
# 690        8.48      PE    scattered clouds  2021-05-21 23:05:44
# 691        3.06      RU       broken clouds  2021-05-21 23:05:45
# 692        7.92      CA     overcast clouds  2021-05-21 23:05:45
# 693        7.25      RU     overcast clouds  2021-05-21 23:05:45
# 694       13.76      MZ       broken clouds  2021-05-21 23:05:45
#
# [695 rows x 10 columns]

# %%
#save dataframe to a csv file 
output_file = ('Weather_Database/WeatherPy_Database.csv')
city_data_df.to_csv(output_file, index_label = 'City ID')
