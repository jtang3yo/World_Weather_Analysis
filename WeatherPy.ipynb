# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations and store them with zip()
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
#You can only unzip a zipped tuple once before it is removed from the computer's memory. 
#Make sure you unzip the latitudes and longitudes into the coordinates list before moving on.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
cities =[]
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates: 
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
# add the city to the cities list if the city is unique 
    if city not in cities: 
        cities.append(city)
len(cities)
# Out:
# 619

# %%
import requests
requests.__version__
# Out:
# '2.25.1'

# %%
import requests
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d3575025f7383208f185effedd3c82a

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
#create an empty list to hold city data 
city_data=[]
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters.
record_count = 1
set_count = 1
#for loop to iterate city and build url for each city 
for i in range(len(cities)): 
# Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
#use the enumerate() method to retrieve both index of cities list and city url 
#reference the index and the city in the list
from datetime import datetime
city_data=[]
for i, city in enumerate(cities): 
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    city_url = url + "&q=" + city.replace(" ","+")
#log the url record 
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    record_count +=1 
#add a try-except block to our code to prevent the API request from stopping prematurely if the city_weather request isn't a valid response.
#try-except block has similar syntax as if-else statement 
    try:
    #parse the json and retrieve the data 
        city_weather = requests.get(city_url).json()
        #parse out needed data 
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
    # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
#if error occurs skip the city
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 13 | rikitea
# Processing Record 2 of Set 13 | souris
# Processing Record 3 of Set 13 | nizip
# Processing Record 4 of Set 13 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 13 | portland
# Processing Record 6 of Set 13 | punta arenas
# Processing Record 7 of Set 13 | aquidauana
# Processing Record 8 of Set 13 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 13 | bathsheba
# Processing Record 10 of Set 13 | kashary
# Processing Record 11 of Set 13 | hilo
# Processing Record 12 of Set 13 | albany
# Processing Record 13 of Set 13 | busselton
# Processing Record 14 of Set 13 | grenada
# Processing Record 15 of Set 13 | grants
# Processing Record 16 of Set 13 | katsuura
# Processing Record 17 of Set 13 | pingchen
# City not found. Skipping...
# Processing Record 18 of Set 13 | chokurdakh
# Processing Record 19 of Set 13 | saint-philippe
# Processing Record 20 of Set 13 | butaritari
# Processing Record 21 of Set 13 | isangel
# Processing Record 22 of Set 13 | vaini
# Processing Record 23 of Set 13 | alvaraes
# Processing Record 24 of Set 13 | calabozo
# Processing Record 25 of Set 13 | dunedin
# Processing Record 26 of Set 13 | okhotsk
# Processing Record 27 of Set 13 | hithadhoo
# Processing Record 28 of Set 13 | mian channun
# Processing Record 29 of Set 13 | caranavi
# Processing Record 30 of Set 13 | jamestown
# Processing Record 31 of Set 13 | abrau-dyurso
# Processing Record 32 of Set 13 | cherskiy
# Processing Record 33 of Set 13 | cape town
# Processing Record 34 of Set 13 | staryy oskol
# Processing Record 35 of Set 13 | burica
# City not found. Skipping...
# Processing Record 36 of Set 13 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 13 | hermanus
# Processing Record 38 of Set 13 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 13 | pacific grove
# Processing Record 40 of Set 13 | ushuaia
# Processing Record 41 of Set 13 | puerto ayora
# Processing Record 42 of Set 13 | sitka
# Processing Record 43 of Set 13 | bluff
# Processing Record 44 of Set 13 | nanortalik
# Processing Record 45 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 46 of Set 13 | torbay
# Processing Record 47 of Set 13 | tasiilaq
# Processing Record 48 of Set 13 | bengkulu
# Processing Record 49 of Set 13 | atuona
# Processing Record 50 of Set 13 | mataura
# Processing Record 1 of Set 14 | lebu
# Processing Record 2 of Set 14 | chuy
# Processing Record 3 of Set 14 | mar del plata
# Processing Record 4 of Set 14 | castro
# Processing Record 5 of Set 14 | nemuro
# Processing Record 6 of Set 14 | pangani
# Processing Record 7 of Set 14 | leningradskiy
# Processing Record 8 of Set 14 | carnarvon
# Processing Record 9 of Set 14 | grindavik
# Processing Record 10 of Set 14 | kruisfontein
# Processing Record 11 of Set 14 | adrar
# Processing Record 12 of Set 14 | hobart
# Processing Record 13 of Set 14 | kaitangata
# Processing Record 14 of Set 14 | norman wells
# Processing Record 15 of Set 14 | pervoye maya
# Processing Record 16 of Set 14 | dikson
# Processing Record 17 of Set 14 | andevoranto
# City not found. Skipping...
# Processing Record 18 of Set 14 | salinas
# Processing Record 19 of Set 14 | providencia
# Processing Record 20 of Set 14 | quatre cocos
# Processing Record 21 of Set 14 | port macquarie
# Processing Record 22 of Set 14 | kodiak
# Processing Record 23 of Set 14 | luderitz
# Processing Record 24 of Set 14 | east london
# Processing Record 25 of Set 14 | pasni
# Processing Record 26 of Set 14 | geraldton
# Processing Record 27 of Set 14 | guerrero negro
# Processing Record 28 of Set 14 | bambous virieux
# Processing Record 29 of Set 14 | arraial do cabo
# Processing Record 30 of Set 14 | yellowknife
# Processing Record 31 of Set 14 | saskylakh
# Processing Record 32 of Set 14 | faya
# Processing Record 33 of Set 14 | viedma
# Processing Record 34 of Set 14 | barra do corda
# Processing Record 35 of Set 14 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 14 | bredasdorp
# Processing Record 37 of Set 14 | ust-nera
# Processing Record 38 of Set 14 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 14 | kapaa
# Processing Record 40 of Set 14 | pangnirtung
# Processing Record 41 of Set 14 | algiers
# Processing Record 42 of Set 14 | abu dhabi
# Processing Record 43 of Set 14 | khatanga
# Processing Record 44 of Set 14 | los llanos de aridane
# Processing Record 45 of Set 14 | cabo san lucas
# Processing Record 46 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 47 of Set 14 | iqaluit
# Processing Record 48 of Set 14 | ormara
# Processing Record 49 of Set 14 | radaur
# Processing Record 50 of Set 14 | ribeira grande
# Processing Record 1 of Set 15 | nantucket
# Processing Record 2 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 15 | maraba
# Processing Record 4 of Set 15 | bayonet point
# Processing Record 5 of Set 15 | valparaiso
# Processing Record 6 of Set 15 | kropotkin
# Processing Record 7 of Set 15 | qaqortoq
# Processing Record 8 of Set 15 | douglas
# Processing Record 9 of Set 15 | nyurba
# Processing Record 10 of Set 15 | beringovskiy
# Processing Record 11 of Set 15 | tuatapere
# Processing Record 12 of Set 15 | lagoa
# Processing Record 13 of Set 15 | qaanaaq
# Processing Record 14 of Set 15 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 15 | det udom
# Processing Record 16 of Set 15 | korla
# Processing Record 17 of Set 15 | kavaratti
# Processing Record 18 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 19 of Set 15 | lompoc
# Processing Record 20 of Set 15 | tiksi
# Processing Record 21 of Set 15 | bereznik
# Processing Record 22 of Set 15 | asau
# Processing Record 23 of Set 15 | barrow
# Processing Record 24 of Set 15 | vila velha
# Processing Record 25 of Set 15 | avarua
# Processing Record 26 of Set 15 | saginaw
# Processing Record 27 of Set 15 | thompson
# Processing Record 28 of Set 15 | hajnowka
# Processing Record 29 of Set 15 | darlowo
# Processing Record 30 of Set 15 | nishihara
# Processing Record 31 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 32 of Set 15 | morro da fumaca
# Processing Record 33 of Set 15 | mangaratiba
# Processing Record 34 of Set 15 | pineville
# Processing Record 35 of Set 15 | mount isa
# Processing Record 36 of Set 15 | college
# Processing Record 37 of Set 15 | rio grande
# Processing Record 38 of Set 15 | brae
# Processing Record 39 of Set 15 | straumen
# Processing Record 40 of Set 15 | kimbe
# Processing Record 41 of Set 15 | new norfolk
# Processing Record 42 of Set 15 | egvekinot
# Processing Record 43 of Set 15 | port alfred
# Processing Record 44 of Set 15 | beloha
# Processing Record 45 of Set 15 | yatou
# Processing Record 46 of Set 15 | itapaci
# Processing Record 47 of Set 15 | port lincoln
# Processing Record 48 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 49 of Set 15 | mount gambier
# Processing Record 50 of Set 15 | lagunas
# Processing Record 1 of Set 16 | clyde river
# Processing Record 2 of Set 16 | malwan
# City not found. Skipping...
# Processing Record 3 of Set 16 | cairns
# Processing Record 4 of Set 16 | longyearbyen
# Processing Record 5 of Set 16 | kieta
# Processing Record 6 of Set 16 | husavik
# Processing Record 7 of Set 16 | bambanglipuro
# Processing Record 8 of Set 16 | dongsheng
# Processing Record 9 of Set 16 | lorengau
# Processing Record 10 of Set 16 | hirara
# Processing Record 11 of Set 16 | luwuk
# Processing Record 12 of Set 16 | hambantota
# Processing Record 13 of Set 16 | esperance
# Processing Record 14 of Set 16 | porto velho
# Processing Record 15 of Set 16 | miri
# Processing Record 16 of Set 16 | wahran
# City not found. Skipping...
# Processing Record 17 of Set 16 | havre
# Processing Record 18 of Set 16 | cockburn town
# Processing Record 19 of Set 16 | nipawin
# Processing Record 20 of Set 16 | altagracia de orituco
# Processing Record 21 of Set 16 | haines junction
# Processing Record 22 of Set 16 | albi
# Processing Record 23 of Set 16 | chapada dos guimaraes
# Processing Record 24 of Set 16 | walpole
# Processing Record 25 of Set 16 | kaeo
# Processing Record 26 of Set 16 | asyut
# Processing Record 27 of Set 16 | avera
# Processing Record 28 of Set 16 | komsomolskiy
# Processing Record 29 of Set 16 | orikhiv
# Processing Record 30 of Set 16 | lavrentiya
# Processing Record 31 of Set 16 | ikom
# Processing Record 32 of Set 16 | bethel
# Processing Record 33 of Set 16 | dawlatabad
# Processing Record 34 of Set 16 | crotone
# Processing Record 35 of Set 16 | afrikanda
# Processing Record 36 of Set 16 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 16 | xinyang
# Processing Record 38 of Set 16 | tuktoyaktuk
# Processing Record 39 of Set 16 | birao
# Processing Record 40 of Set 16 | opuwo
# Processing Record 41 of Set 16 | port elizabeth
# Processing Record 42 of Set 16 | batagay
# Processing Record 43 of Set 16 | nikolskoye
# Processing Record 44 of Set 16 | coalinga
# Processing Record 45 of Set 16 | paramirim
# Processing Record 46 of Set 16 | inhambane
# Processing Record 47 of Set 16 | belmonte
# Processing Record 48 of Set 16 | namtsy
# Processing Record 49 of Set 16 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 16 | acapulco
# Processing Record 1 of Set 17 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 17 | saldanha
# Processing Record 3 of Set 17 | havre-saint-pierre
# Processing Record 4 of Set 17 | hofn
# Processing Record 5 of Set 17 | gimbi
# Processing Record 6 of Set 17 | grand gaube
# Processing Record 7 of Set 17 | aklavik
# Processing Record 8 of Set 17 | twante
# Processing Record 9 of Set 17 | fortuna
# Processing Record 10 of Set 17 | morondava
# Processing Record 11 of Set 17 | tautira
# Processing Record 12 of Set 17 | sauda
# Processing Record 13 of Set 17 | coquimbo
# Processing Record 14 of Set 17 | narsaq
# Processing Record 15 of Set 17 | klaksvik
# Processing Record 16 of Set 17 | tazovskiy
# Processing Record 17 of Set 17 | zwedru
# Processing Record 18 of Set 17 | moche
# Processing Record 19 of Set 17 | islamkot
# Processing Record 20 of Set 17 | hualmay
# Processing Record 21 of Set 17 | port hardy
# Processing Record 22 of Set 17 | zaysan
# Processing Record 23 of Set 17 | payo
# Processing Record 24 of Set 17 | upernavik
# Processing Record 25 of Set 17 | codrington
# Processing Record 26 of Set 17 | pevek
# Processing Record 27 of Set 17 | russell
# Processing Record 28 of Set 17 | montrose
# Processing Record 29 of Set 17 | srednekolymsk
# Processing Record 30 of Set 17 | mahebourg
# Processing Record 31 of Set 17 | tidore
# City not found. Skipping...
# Processing Record 32 of Set 17 | kahului
# Processing Record 33 of Set 17 | dombarovskiy
# Processing Record 34 of Set 17 | batagay-alyta
# Processing Record 35 of Set 17 | mont-dore
# Processing Record 36 of Set 17 | cidreira
# Processing Record 37 of Set 17 | poros
# Processing Record 38 of Set 17 | prince rupert
# Processing Record 39 of Set 17 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 17 | portmore
# Processing Record 41 of Set 17 | maputo
# Processing Record 42 of Set 17 | havoysund
# Processing Record 43 of Set 17 | birin
# Processing Record 44 of Set 17 | moose factory
# Processing Record 45 of Set 17 | emerald
# Processing Record 46 of Set 17 | mollendo
# Processing Record 47 of Set 17 | sinjah
# City not found. Skipping...
# Processing Record 48 of Set 17 | rawatbhata
# Processing Record 49 of Set 17 | port-cartier
# Processing Record 50 of Set 17 | san cristobal
# Processing Record 1 of Set 18 | jambi
# Processing Record 2 of Set 18 | abu samrah
# Processing Record 3 of Set 18 | port hawkesbury
# Processing Record 4 of Set 18 | evensk
# Processing Record 5 of Set 18 | necochea
# Processing Record 6 of Set 18 | kommunisticheskiy
# Processing Record 7 of Set 18 | ilulissat
# Processing Record 8 of Set 18 | bartica
# Processing Record 9 of Set 18 | scarborough
# Processing Record 10 of Set 18 | keti bandar
# Processing Record 11 of Set 18 | collie
# Processing Record 12 of Set 18 | coahuayana
# Processing Record 13 of Set 18 | nacimiento
# Processing Record 14 of Set 18 | vallenar
# Processing Record 15 of Set 18 | san ramon
# Processing Record 16 of Set 18 | roma
# Processing Record 17 of Set 18 | airai
# Processing Record 18 of Set 18 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 18 | banda aceh
# Processing Record 20 of Set 18 | meulaboh
# Processing Record 21 of Set 18 | linxia
# Processing Record 22 of Set 18 | talnakh
# Processing Record 23 of Set 18 | rabo de peixe
# Processing Record 24 of Set 18 | den helder
# Processing Record 25 of Set 18 | atocha
# Processing Record 26 of Set 18 | neiafu
# Processing Record 27 of Set 18 | tawau
# Processing Record 28 of Set 18 | potiskum
# Processing Record 29 of Set 18 | cascais
# Processing Record 30 of Set 18 | padang
# Processing Record 31 of Set 18 | koygorodok
# Processing Record 32 of Set 18 | katobu
# Processing Record 33 of Set 18 | svetlogorsk
# Processing Record 34 of Set 18 | tilichiki
# Processing Record 35 of Set 18 | samalaeulu
# City not found. Skipping...
# Processing Record 36 of Set 18 | pochutla
# Processing Record 37 of Set 18 | saint-pierre
# Processing Record 38 of Set 18 | muisne
# Processing Record 39 of Set 18 | saint george
# Processing Record 40 of Set 18 | slonim
# Processing Record 41 of Set 18 | ostrovnoy
# Processing Record 42 of Set 18 | georgetown
# Processing Record 43 of Set 18 | mazyr
# Processing Record 44 of Set 18 | hasaki
# Processing Record 45 of Set 18 | nome
# Processing Record 46 of Set 18 | axim
# Processing Record 47 of Set 18 | kokkola
# Processing Record 48 of Set 18 | loughborough
# Processing Record 49 of Set 18 | sao joao da barra
# Processing Record 50 of Set 18 | koungou
# Processing Record 1 of Set 19 | atkinson
# Processing Record 2 of Set 19 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 19 | bozova
# Processing Record 4 of Set 19 | palauig
# Processing Record 5 of Set 19 | banjar
# Processing Record 6 of Set 19 | baleshwar
# Processing Record 7 of Set 19 | kosh-agach
# Processing Record 8 of Set 19 | acajutla
# Processing Record 9 of Set 19 | tigzirt
# Processing Record 10 of Set 19 | north bend
# Processing Record 11 of Set 19 | dagana
# Processing Record 12 of Set 19 | sinnamary
# Processing Record 13 of Set 19 | simao
# Processing Record 14 of Set 19 | constitucion
# Processing Record 15 of Set 19 | petropavlovka
# Processing Record 16 of Set 19 | tawkar
# City not found. Skipping...
# Processing Record 17 of Set 19 | russkaya polyana
# Processing Record 18 of Set 19 | oranjestad
# Processing Record 19 of Set 19 | lasa
# Processing Record 20 of Set 19 | sigerfjord
# City not found. Skipping...
# Processing Record 21 of Set 19 | pingliang
# Processing Record 22 of Set 19 | vao
# Processing Record 23 of Set 19 | luang prabang
# Processing Record 24 of Set 19 | severo-kurilsk
# Processing Record 25 of Set 19 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 19 | tougan
# Processing Record 27 of Set 19 | bubaque
# Processing Record 28 of Set 19 | santa rosa
# Processing Record 29 of Set 19 | vila
# Processing Record 30 of Set 19 | broken hill
# Processing Record 31 of Set 19 | pierre
# Processing Record 32 of Set 19 | karratha
# Processing Record 33 of Set 19 | mocajuba
# Processing Record 34 of Set 19 | riyadh
# Processing Record 35 of Set 19 | richards bay
# Processing Record 36 of Set 19 | poltava
# Processing Record 37 of Set 19 | huancavelica
# Processing Record 38 of Set 19 | dalbandin
# Processing Record 39 of Set 19 | hammerfest
# Processing Record 40 of Set 19 | alice springs
# Processing Record 41 of Set 19 | sawtell
# Processing Record 42 of Set 19 | san quintin
# Processing Record 43 of Set 19 | buraydah
# Processing Record 44 of Set 19 | aksu
# Processing Record 45 of Set 19 | cayenne
# Processing Record 46 of Set 19 | conde
# Processing Record 47 of Set 19 | magistralnyy
# Processing Record 48 of Set 19 | yantal
# Processing Record 49 of Set 19 | ajdabiya
# Processing Record 50 of Set 19 | seguela
# Processing Record 1 of Set 20 | juneau
# Processing Record 2 of Set 20 | namibe
# Processing Record 3 of Set 20 | la ronge
# Processing Record 4 of Set 20 | puerto escondido
# Processing Record 5 of Set 20 | davila
# Processing Record 6 of Set 20 | agirish
# Processing Record 7 of Set 20 | shumskiy
# Processing Record 8 of Set 20 | sakaiminato
# Processing Record 9 of Set 20 | kedrovyy
# Processing Record 10 of Set 20 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 20 | berlevag
# Processing Record 12 of Set 20 | sturgis
# Processing Record 13 of Set 20 | purpe
# Processing Record 14 of Set 20 | kamaishi
# Processing Record 15 of Set 20 | woodbury
# Processing Record 16 of Set 20 | golden
# Processing Record 17 of Set 20 | port augusta
# Processing Record 18 of Set 20 | kavieng
# Processing Record 19 of Set 20 | caravelas
# Processing Record 20 of Set 20 | celestun
# Processing Record 21 of Set 20 | saint-francois
# Processing Record 22 of Set 20 | zhanakorgan
# Processing Record 23 of Set 20 | hyeres
# Processing Record 24 of Set 20 | saint-joseph
# Processing Record 25 of Set 20 | victoria
# Processing Record 26 of Set 20 | ca mau
# Processing Record 27 of Set 20 | salalah
# Processing Record 28 of Set 20 | chimbote
# Processing Record 29 of Set 20 | fare
# Processing Record 30 of Set 20 | euclid
# Processing Record 31 of Set 20 | nam tha
# City not found. Skipping...
# Processing Record 32 of Set 20 | antofagasta
# Processing Record 33 of Set 20 | raudeberg
# Processing Record 34 of Set 20 | paamiut
# Processing Record 35 of Set 20 | varhaug
# Processing Record 36 of Set 20 | naze
# Processing Record 37 of Set 20 | hun
# Processing Record 38 of Set 20 | mehamn
# Processing Record 39 of Set 20 | mecca
# Processing Record 40 of Set 20 | payson
# Processing Record 41 of Set 20 | matara
# Processing Record 42 of Set 20 | corn island
# Processing Record 43 of Set 20 | colesberg
# Processing Record 44 of Set 20 | talara
# Processing Record 45 of Set 20 | road town
# Processing Record 46 of Set 20 | krasnomayskiy
# Processing Record 47 of Set 20 | santa isabel do rio negro
# Processing Record 48 of Set 20 | ambodifototra
# City not found. Skipping...
# Processing Record 49 of Set 20 | ancud
# Processing Record 50 of Set 20 | longlac
# City not found. Skipping...
# Processing Record 1 of Set 21 | bereda
# Processing Record 2 of Set 21 | ulaangom
# Processing Record 3 of Set 21 | te anau
# Processing Record 4 of Set 21 | esna
# Processing Record 5 of Set 21 | olga
# Processing Record 6 of Set 21 | buqayq
# City not found. Skipping...
# Processing Record 7 of Set 21 | yenagoa
# Processing Record 8 of Set 21 | qena
# Processing Record 9 of Set 21 | alofi
# Processing Record 10 of Set 21 | acarau
# Processing Record 11 of Set 21 | sembakung
# Processing Record 12 of Set 21 | union
# Processing Record 13 of Set 21 | yaring
# Processing Record 14 of Set 21 | ozernovskiy
# Processing Record 15 of Set 21 | sur
# Processing Record 16 of Set 21 | luchenza
# Processing Record 17 of Set 21 | batouri
# Processing Record 18 of Set 21 | ponta do sol
# Processing Record 19 of Set 21 | goderich
# Processing Record 20 of Set 21 | pachora
# Processing Record 21 of Set 21 | alyangula
# Processing Record 22 of Set 21 | darnah
# Processing Record 23 of Set 21 | san patricio
# Processing Record 24 of Set 21 | meyungs
# City not found. Skipping...
# Processing Record 25 of Set 21 | cedar city
# Processing Record 26 of Set 21 | bandarban
# Processing Record 27 of Set 21 | griffith
# Processing Record 28 of Set 21 | lensk
# Processing Record 29 of Set 21 | broome
# Processing Record 30 of Set 21 | edgewater
# Processing Record 31 of Set 21 | dingle
# Processing Record 32 of Set 21 | margate
# Processing Record 33 of Set 21 | matanzas
# Processing Record 34 of Set 21 | vidim
# Processing Record 35 of Set 21 | taoudenni
# Processing Record 36 of Set 21 | kanker
# Processing Record 37 of Set 21 | palu
# Processing Record 38 of Set 21 | souillac
# Processing Record 39 of Set 21 | taywarah
# Processing Record 40 of Set 21 | mehran
# Processing Record 41 of Set 21 | louisbourg
# City not found. Skipping...
# Processing Record 42 of Set 21 | bandarbeyla
# Processing Record 43 of Set 21 | conceicao do araguaia
# Processing Record 44 of Set 21 | limon
# Processing Record 45 of Set 21 | kismayo
# Processing Record 46 of Set 21 | monduli
# Processing Record 47 of Set 21 | rafai
# Processing Record 48 of Set 21 | shitanjing
# Processing Record 49 of Set 21 | pisco
# Processing Record 50 of Set 21 | agadir
# Processing Record 1 of Set 22 | vostok
# Processing Record 2 of Set 22 | babanusah
# City not found. Skipping...
# Processing Record 3 of Set 22 | kashira
# Processing Record 4 of Set 22 | khani
# Processing Record 5 of Set 22 | touros
# Processing Record 6 of Set 22 | chatrapur
# Processing Record 7 of Set 22 | mackay
# Processing Record 8 of Set 22 | chagda
# City not found. Skipping...
# Processing Record 9 of Set 22 | vavatenina
# Processing Record 10 of Set 22 | mokhotlong
# Processing Record 11 of Set 22 | bara
# Processing Record 12 of Set 22 | shimoda
# Processing Record 13 of Set 22 | campestre
# Processing Record 14 of Set 22 | provideniya
# Processing Record 15 of Set 22 | balezino
# Processing Record 16 of Set 22 | zemio
# Processing Record 17 of Set 22 | grand centre
# City not found. Skipping...
# Processing Record 18 of Set 22 | sorong
# Processing Record 19 of Set 22 | saint-augustin
# Processing Record 20 of Set 22 | tainan
# Processing Record 21 of Set 22 | mrirt
# City not found. Skipping...
# Processing Record 22 of Set 22 | brigantine
# Processing Record 23 of Set 22 | ayagoz
# Processing Record 24 of Set 22 | pascagoula
# Processing Record 25 of Set 22 | rize
# Processing Record 26 of Set 22 | tessalit
# Processing Record 27 of Set 22 | zvenigovo
# Processing Record 28 of Set 22 | shakawe
# Processing Record 29 of Set 22 | kelo
# Processing Record 30 of Set 22 | muzaffarabad
# Processing Record 31 of Set 22 | vanimo
# Processing Record 32 of Set 22 | tharad
# Processing Record 33 of Set 22 | zeya
# Processing Record 34 of Set 22 | sri aman
# Processing Record 35 of Set 22 | jalu
# Processing Record 36 of Set 22 | monywa
# Processing Record 37 of Set 22 | candido mendes
# Processing Record 38 of Set 22 | upington
# Processing Record 39 of Set 22 | gudari
# Processing Record 40 of Set 22 | san felipe
# Processing Record 41 of Set 22 | leh
# Processing Record 42 of Set 22 | srivardhan
# Processing Record 43 of Set 22 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 44 of Set 22 | lolua
# City not found. Skipping...
# Processing Record 45 of Set 22 | tubruq
# City not found. Skipping...
# Processing Record 46 of Set 22 | port-gentil
# Processing Record 47 of Set 22 | maneromango
# Processing Record 48 of Set 22 | powell river
# Processing Record 49 of Set 22 | tumpat
# Processing Record 50 of Set 22 | vila franca do campo
# Processing Record 1 of Set 23 | dwarka
# Processing Record 2 of Set 23 | langsa
# Processing Record 3 of Set 23 | kibre mengist
# Processing Record 4 of Set 23 | miraflores
# Processing Record 5 of Set 23 | paraiso
# Processing Record 6 of Set 23 | nikolayevka
# Processing Record 7 of Set 23 | uyuni
# Processing Record 8 of Set 23 | bilibino
# Processing Record 9 of Set 23 | luanda
# Processing Record 10 of Set 23 | chicama
# Processing Record 11 of Set 23 | olivenza
# Processing Record 12 of Set 23 | tabou
# Processing Record 13 of Set 23 | iracoubo
# Processing Record 14 of Set 23 | uvat
# Processing Record 15 of Set 23 | port moresby
# Processing Record 16 of Set 23 | townsville
# Processing Record 17 of Set 23 | peterhead
# Processing Record 18 of Set 23 | byron bay
# Processing Record 19 of Set 23 | manono
# Processing Record 20 of Set 23 | onokhino
# Processing Record 21 of Set 23 | berdigestyakh
# Processing Record 22 of Set 23 | ugoofaaru
# Processing Record 23 of Set 23 | asuncion
# Processing Record 24 of Set 23 | parintins
# Processing Record 25 of Set 23 | geresk
# City not found. Skipping...
# Processing Record 26 of Set 23 | skibbereen
# Processing Record 27 of Set 23 | kendari
# Processing Record 28 of Set 23 | mangan
# Processing Record 29 of Set 23 | ossora
# Processing Record 30 of Set 23 | bam
# Processing Record 31 of Set 23 | parana
# Processing Record 32 of Set 23 | rawson
# Processing Record 33 of Set 23 | turtkul
# City not found. Skipping...
# Processing Record 34 of Set 23 | mnogovershinnyy
# Processing Record 35 of Set 23 | tambura
# Processing Record 36 of Set 23 | ambon
# Processing Record 37 of Set 23 | kuala terengganu
# Processing Record 38 of Set 23 | vestmanna
# Processing Record 39 of Set 23 | maniitsoq
# Processing Record 40 of Set 23 | seydisehir
# Processing Record 41 of Set 23 | diffa
# Processing Record 42 of Set 23 | santa vitoria do palmar
# Processing Record 43 of Set 23 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 23 | great bend
# Processing Record 45 of Set 23 | torgau
# Processing Record 46 of Set 23 | muzhi
# Processing Record 47 of Set 23 | tigre
# Processing Record 48 of Set 23 | nioro
# Processing Record 49 of Set 23 | tabid
# Processing Record 50 of Set 23 | leiyang
# Processing Record 1 of Set 24 | tibati
# Processing Record 2 of Set 24 | utiroa
# City not found. Skipping...
# Processing Record 3 of Set 24 | ko samui
# Processing Record 4 of Set 24 | sao filipe
# Processing Record 5 of Set 24 | rongcheng
# Processing Record 6 of Set 24 | mezen
# Processing Record 7 of Set 24 | kawalu
# Processing Record 8 of Set 24 | warqla
# City not found. Skipping...
# Processing Record 9 of Set 24 | santa marta
# Processing Record 10 of Set 24 | viligili
# City not found. Skipping...
# Processing Record 11 of Set 24 | la granja
# Processing Record 12 of Set 24 | satinka
# Processing Record 13 of Set 24 | mponela
# Processing Record 14 of Set 24 | thinadhoo
# Processing Record 15 of Set 24 | nouadhibou
# Processing Record 16 of Set 24 | gobabis
# Processing Record 17 of Set 24 | aswan
# Processing Record 18 of Set 24 | mackenzie
# Processing Record 19 of Set 24 | halifax
# Processing Record 20 of Set 24 | gafanha da encarnacao
# Processing Record 21 of Set 24 | maarianhamina
# Processing Record 22 of Set 24 | bargal
# City not found. Skipping...
# Processing Record 23 of Set 24 | rocha
# Processing Record 24 of Set 24 | de-kastri
# Processing Record 25 of Set 24 | pumiao
# Processing Record 26 of Set 24 | mattru
# Processing Record 27 of Set 24 | sicamous
# Processing Record 28 of Set 24 | falam
# Processing Record 29 of Set 24 | rybnoye
# Processing Record 30 of Set 24 | lagos
# Processing Record 31 of Set 24 | buariki
# City not found. Skipping...
# Processing Record 32 of Set 24 | vestmannaeyjar
# Processing Record 33 of Set 24 | faanui
# Processing Record 34 of Set 24 | pearl
# Processing Record 35 of Set 24 | aflu
# City not found. Skipping...
# Processing Record 36 of Set 24 | zhenlai
# Processing Record 37 of Set 24 | ransang
# Processing Record 38 of Set 24 | bhuj
# Processing Record 39 of Set 24 | irun
# Processing Record 40 of Set 24 | vilhena
# Processing Record 41 of Set 24 | superior
# Processing Record 42 of Set 24 | trapani
# Processing Record 43 of Set 24 | ambilobe
# Processing Record 44 of Set 24 | chilliwack
# Processing Record 45 of Set 24 | torbat-e jam
# Processing Record 46 of Set 24 | san pedro de ycuamandiyu
# Processing Record 47 of Set 24 | ladario
# Processing Record 48 of Set 24 | kadykchan
# City not found. Skipping...
# Processing Record 49 of Set 24 | tateyama
# Processing Record 50 of Set 24 | awbari
# Processing Record 1 of Set 25 | sangueya
# Processing Record 2 of Set 25 | san andres
# Processing Record 3 of Set 25 | sola
# Processing Record 4 of Set 25 | juifang
# City not found. Skipping...
# Processing Record 5 of Set 25 | namatanai
# Processing Record 6 of Set 25 | san angelo
# Processing Record 7 of Set 25 | lat yao
# Processing Record 8 of Set 25 | alta floresta
# Processing Record 9 of Set 25 | hami
# Processing Record 10 of Set 25 | sorland
# Processing Record 11 of Set 25 | rio gallegos
# Processing Record 12 of Set 25 | ternate
# Processing Record 13 of Set 25 | inuvik
# Processing Record 14 of Set 25 | bolkhov
# Processing Record 15 of Set 25 | manadhoo
# Processing Record 16 of Set 25 | yeppoon
# Processing Record 17 of Set 25 | nelson bay
# Processing Record 18 of Set 25 | kuching
# Processing Record 19 of Set 25 | bowen
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 564

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Rikitea -23.1203 -134.9692     75.04        61         100
# 1        Souris  49.6172 -100.2612     82.40        16          75
# 2         Nizip  37.0097   37.7942     66.20        34           0
# 3      Portland  45.5234 -122.6762     80.01        43           1
# 4  Punta Arenas -53.1500  -70.9167     44.60       100          90
#
#    Wind Speed Country                 Date
# 0       10.92      PF  2021-05-16 20:29:55
# 1       21.85      CA  2021-05-16 20:32:29
# 2        3.44      TR  2021-05-16 20:32:29
# 3        8.05      US  2021-05-16 20:30:14
# 4       14.97      CL  2021-05-16 20:29:54

# %%
new_column_order = ["City",'Country','Date','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed']
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0       Rikitea      PF  2021-05-16 20:29:55 -23.1203 -134.9692     75.04
# 1        Souris      CA  2021-05-16 20:32:29  49.6172 -100.2612     82.40
# 2         Nizip      TR  2021-05-16 20:32:29  37.0097   37.7942     66.20
# 3      Portland      US  2021-05-16 20:30:14  45.5234 -122.6762     80.01
# 4  Punta Arenas      CL  2021-05-16 20:29:54 -53.1500  -70.9167     44.60
# 5    Aquidauana      BR  2021-05-16 20:32:30 -20.4711  -55.7872     86.04
# 6     Bathsheba      BB  2021-05-16 20:31:47  13.2167  -59.5167     84.20
# 7       Kashary      RU  2021-05-16 20:32:30  49.0400   41.0056     64.94
# 8          Hilo      US  2021-05-16 20:30:08  19.7297 -155.0900     84.20
# 9        Albany      US  2021-05-16 20:29:19  42.6001  -73.9662     75.00
#
#    Humidity  Cloudiness  Wind Speed
# 0        61         100       10.92
# 1        16          75       21.85
# 2        34           0        3.44
# 3        43           1        8.05
# 4       100          90       14.97
# 5        29          64        2.86
# 6        61          40       19.57
# 7        53          96       10.47
# 8        51          90        9.22
# 9        27          75        9.22

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label='City_ID')

# %%
#extract relevant fields from dataframe for plotting 
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]
import time 
today = time.time()
today
# Out:
# 1621197272.8654442

# %%
today = time.strftime("%x")
today
# Out:
# '05/16/21'

# %%
#add time.strftime("%x") to our plt.title() function in our scatter plot.
import time 
plt.scatter(lats,
           max_temps,
           edgecolor = 'black', linewidth = 1,
            marker = 'o',alpha = 0.8, label="Cities")
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("weather_data/Fig1.png")
plt.show()

# %%
#change the yaxis to humidity 
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
#latitude vs. cloudiness 
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
#latitude vs. wind speed. 
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")
# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
from scipy.stats import linregress
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    regress_values = x_values * slope  + intercept 
    line_eq = 'y=' + str(round(slope,2)) + 'x+'+ str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
#apply loc() in city_data_df to create hemisphere datafram 
index13 = city_data_df.loc[13]
index13
# Out:
# City                     Katsuura
# Country                        JP
# Date          2021-05-16 20:30:27
# Lat                       35.1333
# Lng                         140.3
# Max Temp                     73.0
# Humidity                      100
# Cloudiness                     75
# Wind Speed                  18.41
# Name: 13, dtype: object

# %%
#or filter the latitude > 0 for north hemisphere 
city_data_df['Lat']>=0
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 559     True
# 560    False
# 561    False
# 562     True
# 563    False
# Name: Lat, Length: 564, dtype: bool

# %%
#use loc[condition lat>=0] to filter south and north hemisphere 
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']
# Call the function.
plot_linear_regression(x_values, y_values, 
                       'Linear Regression on the Northern Hemisphere for Maximum Temperature', 'Max Temp',(10,40))
#change the text coordinates until see the equation

# %%
# linear regression on southern hemi 
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']
plot_linear_regression(x_values, y_values,'Linear Regression on the Southern Hemisphere for Maximum Temperature',
                      'Max Temp', (-50,90))

# %%
#linear regression of northern hemi lat and humidity 
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']
plot_linear_regression(x_values, y_values, 'Linear Regression on Northern Hemisphere for % Humidity',
                      '% Humidity', (40,10))

# %%
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']
plot_linear_regression(x_values, y_values, 'Linear Regression on Southern Hemisphere for % Humidity',
                      '% Humidity', (-50,15))

# %%
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']
plot_linear_regression(x_values, y_values, 'Linear Regression on Northern Hemisphere for % Cloudiness',
                      '% Cloudiness', (40,10))

# %%
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']
plot_linear_regression(x_values, y_values, 'Linear Regression on Southern Hemisphere for % Cloudiness',
                      '% Cloudiness', (-50,15))

# %%
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']
plot_linear_regression(x_values, y_values, 'Linear Regression on Northern Hemisphere for Wind Speed',
                      'Wind Speed', (40,10))

# %%
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']
plot_linear_regression(x_values, y_values, 'Linear Regression on Southern Hemisphere for Wind Speed',
                      'Wind Speed', (-50,15))
