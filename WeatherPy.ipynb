# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations and store them with zip()
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
#You can only unzip a zipped tuple once before it is removed from the computer's memory. 
#Make sure you unzip the latitudes and longitudes into the coordinates list before moving on.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
cities =[]
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates: 
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
# add the city to the cities list if the city is unique 
    if city not in cities: 
        cities.append(city)
len(cities)
# Out:
# 592

# %%
import requests
requests.__version__
# Out:
# '2.25.1'

# %%
import requests
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d3575025f7383208f185effedd3c82a

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
#create an empty list to hold city data 
city_data=[]
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters.
record_count = 1
set_count = 1
#for loop to iterate city and build url for each city 
for i in range(len(cities)): 
# Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
#use the enumerate() method to retrieve both index of cities list and city url 
#reference the index and the city in the list
from datetime import datetime
city_data=[]
for i, city in enumerate(cities): 
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    city_url = url + "&q=" + city.replace(" ","+")
#log the url record 
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    record_count +=1 
#add a try-except block to our code to prevent the API request from stopping prematurely if the city_weather request isn't a valid response.
#try-except block has similar syntax as if-else statement 
    try:
    #parse the json and retrieve the data 
        city_weather = requests.get(city_url).json()
        #parse out needed data 
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
    # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
#if error occurs skip the city
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 12 | chokurdakh
# Processing Record 2 of Set 12 | lasa
# Processing Record 3 of Set 12 | fairmont
# Processing Record 4 of Set 12 | arraial do cabo
# Processing Record 5 of Set 12 | butaritari
# Processing Record 6 of Set 12 | busselton
# Processing Record 7 of Set 12 | dunedin
# Processing Record 8 of Set 12 | puerto escondido
# Processing Record 9 of Set 12 | mataura
# Processing Record 10 of Set 12 | kapaa
# Processing Record 11 of Set 12 | jamestown
# Processing Record 12 of Set 12 | gazojak
# Processing Record 13 of Set 12 | albany
# Processing Record 14 of Set 12 | pangody
# Processing Record 15 of Set 12 | asilah
# Processing Record 16 of Set 12 | mar del plata
# Processing Record 17 of Set 12 | dikson
# Processing Record 18 of Set 12 | bluff
# Processing Record 19 of Set 12 | puerto ayora
# Processing Record 20 of Set 12 | naron
# Processing Record 21 of Set 12 | igrim
# Processing Record 22 of Set 12 | leningradskiy
# Processing Record 23 of Set 12 | rikitea
# Processing Record 24 of Set 12 | pangnirtung
# Processing Record 25 of Set 12 | ushuaia
# Processing Record 26 of Set 12 | tuktoyaktuk
# Processing Record 27 of Set 12 | tiznit
# Processing Record 28 of Set 12 | qabis
# City not found. Skipping...
# Processing Record 29 of Set 12 | ponta delgada
# Processing Record 30 of Set 12 | georgetown
# Processing Record 31 of Set 12 | cherskiy
# Processing Record 32 of Set 12 | cocachacra
# Processing Record 33 of Set 12 | sambava
# Processing Record 34 of Set 12 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 12 | atar
# Processing Record 36 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 12 | bacolod
# Processing Record 38 of Set 12 | naze
# Processing Record 39 of Set 12 | vaini
# Processing Record 40 of Set 12 | deputatskiy
# Processing Record 41 of Set 12 | hermanus
# Processing Record 42 of Set 12 | atuona
# Processing Record 43 of Set 12 | alice springs
# Processing Record 44 of Set 12 | hilo
# Processing Record 45 of Set 12 | chuy
# Processing Record 46 of Set 12 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 12 | qaanaaq
# Processing Record 49 of Set 12 | punta arenas
# Processing Record 50 of Set 12 | kavaratti
# Processing Record 1 of Set 13 | mahebourg
# Processing Record 2 of Set 13 | upernavik
# Processing Record 3 of Set 13 | nikolskoye
# Processing Record 4 of Set 13 | srednekolymsk
# Processing Record 5 of Set 13 | nizhniy ufaley
# Processing Record 6 of Set 13 | saskylakh
# Processing Record 7 of Set 13 | marsh harbour
# Processing Record 8 of Set 13 | nanortalik
# Processing Record 9 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 10 of Set 13 | east london
# Processing Record 11 of Set 13 | lavrentiya
# Processing Record 12 of Set 13 | barrow
# Processing Record 13 of Set 13 | ramet
# Processing Record 14 of Set 13 | riyadh
# Processing Record 15 of Set 13 | baruun-urt
# Processing Record 16 of Set 13 | saint-philippe
# Processing Record 17 of Set 13 | port elizabeth
# Processing Record 18 of Set 13 | eureka
# Processing Record 19 of Set 13 | pasaquina
# Processing Record 20 of Set 13 | lukovetskiy
# Processing Record 21 of Set 13 | goundi
# Processing Record 22 of Set 13 | seymchan
# Processing Record 23 of Set 13 | rio cuarto
# Processing Record 24 of Set 13 | hithadhoo
# Processing Record 25 of Set 13 | ilesha
# Processing Record 26 of Set 13 | suntar
# Processing Record 27 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 13 | kouango
# Processing Record 29 of Set 13 | les cayes
# Processing Record 30 of Set 13 | beloha
# Processing Record 31 of Set 13 | guerrero negro
# Processing Record 32 of Set 13 | kristiansund
# Processing Record 33 of Set 13 | pevek
# Processing Record 34 of Set 13 | norman wells
# Processing Record 35 of Set 13 | coquimbo
# Processing Record 36 of Set 13 | merauke
# Processing Record 37 of Set 13 | bredasdorp
# Processing Record 38 of Set 13 | nome
# Processing Record 39 of Set 13 | hofn
# Processing Record 40 of Set 13 | geraldton
# Processing Record 41 of Set 13 | carnarvon
# Processing Record 42 of Set 13 | fuzhou
# Processing Record 43 of Set 13 | amapa
# Processing Record 44 of Set 13 | poum
# Processing Record 45 of Set 13 | makhachkala
# Processing Record 46 of Set 13 | severo-kurilsk
# Processing Record 47 of Set 13 | nara
# Processing Record 48 of Set 13 | cape town
# Processing Record 49 of Set 13 | broome
# Processing Record 50 of Set 13 | mehamn
# Processing Record 1 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 2 of Set 14 | jalu
# Processing Record 3 of Set 14 | kodiak
# Processing Record 4 of Set 14 | nemuro
# Processing Record 5 of Set 14 | la ronge
# Processing Record 6 of Set 14 | rosarito
# Processing Record 7 of Set 14 | zaozhuang
# Processing Record 8 of Set 14 | mujiayingzi
# Processing Record 9 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 10 of Set 14 | ilulissat
# Processing Record 11 of Set 14 | skalistyy
# City not found. Skipping...
# Processing Record 12 of Set 14 | mahendragarh
# Processing Record 13 of Set 14 | thunder bay
# Processing Record 14 of Set 14 | new norfolk
# Processing Record 15 of Set 14 | khatanga
# Processing Record 16 of Set 14 | taltal
# Processing Record 17 of Set 14 | hambantota
# Processing Record 18 of Set 14 | thenzawl
# Processing Record 19 of Set 14 | ambon
# Processing Record 20 of Set 14 | tasiilaq
# Processing Record 21 of Set 14 | male
# Processing Record 22 of Set 14 | yar-sale
# Processing Record 23 of Set 14 | phan rang
# City not found. Skipping...
# Processing Record 24 of Set 14 | luderitz
# Processing Record 25 of Set 14 | manggar
# Processing Record 26 of Set 14 | kingswood
# Processing Record 27 of Set 14 | sao filipe
# Processing Record 28 of Set 14 | sungairaya
# Processing Record 29 of Set 14 | half moon bay
# Processing Record 30 of Set 14 | pokhara
# Processing Record 31 of Set 14 | clyde river
# Processing Record 32 of Set 14 | pineville
# Processing Record 33 of Set 14 | klaksvik
# Processing Record 34 of Set 14 | bull savanna
# Processing Record 35 of Set 14 | hay river
# Processing Record 36 of Set 14 | kastron
# City not found. Skipping...
# Processing Record 37 of Set 14 | bethel
# Processing Record 38 of Set 14 | sechura
# Processing Record 39 of Set 14 | wamba
# Processing Record 40 of Set 14 | lompoc
# Processing Record 41 of Set 14 | katobu
# Processing Record 42 of Set 14 | galveston
# Processing Record 43 of Set 14 | fairbanks
# Processing Record 44 of Set 14 | mount isa
# Processing Record 45 of Set 14 | kavieng
# Processing Record 46 of Set 14 | lugovskiy
# City not found. Skipping...
# Processing Record 47 of Set 14 | cidreira
# Processing Record 48 of Set 14 | nioro
# Processing Record 49 of Set 14 | ust-kuyga
# Processing Record 50 of Set 14 | yellowknife
# Processing Record 1 of Set 15 | salalah
# Processing Record 2 of Set 15 | narayangarh
# Processing Record 3 of Set 15 | kieta
# Processing Record 4 of Set 15 | muroto
# Processing Record 5 of Set 15 | santa rosa
# Processing Record 6 of Set 15 | asau
# Processing Record 7 of Set 15 | weligama
# Processing Record 8 of Set 15 | balaguer
# Processing Record 9 of Set 15 | morondava
# Processing Record 10 of Set 15 | port alfred
# Processing Record 11 of Set 15 | sao miguel do araguaia
# Processing Record 12 of Set 15 | nur
# Processing Record 13 of Set 15 | castro
# Processing Record 14 of Set 15 | baglung
# Processing Record 15 of Set 15 | awbari
# Processing Record 16 of Set 15 | avarua
# Processing Record 17 of Set 15 | kaitangata
# Processing Record 18 of Set 15 | esperance
# Processing Record 19 of Set 15 | mana
# Processing Record 20 of Set 15 | provideniya
# Processing Record 21 of Set 15 | tuatapere
# Processing Record 22 of Set 15 | doha
# Processing Record 23 of Set 15 | iqaluit
# Processing Record 24 of Set 15 | camacha
# Processing Record 25 of Set 15 | westport
# Processing Record 26 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 15 | hasaki
# Processing Record 28 of Set 15 | thompson
# Processing Record 29 of Set 15 | berezovyy
# Processing Record 30 of Set 15 | jabiru
# City not found. Skipping...
# Processing Record 31 of Set 15 | ambodifototra
# City not found. Skipping...
# Processing Record 32 of Set 15 | vila franca do campo
# Processing Record 33 of Set 15 | veraval
# Processing Record 34 of Set 15 | sirnak
# Processing Record 35 of Set 15 | binga
# Processing Record 36 of Set 15 | maneadero
# Processing Record 37 of Set 15 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 15 | osoyoos
# Processing Record 39 of Set 15 | hobart
# Processing Record 40 of Set 15 | pulo
# Processing Record 41 of Set 15 | patiya
# Processing Record 42 of Set 15 | dubbo
# Processing Record 43 of Set 15 | aklavik
# Processing Record 44 of Set 15 | sukhobezvodnoye
# Processing Record 45 of Set 15 | baykit
# Processing Record 46 of Set 15 | nanakuli
# Processing Record 47 of Set 15 | port hawkesbury
# Processing Record 48 of Set 15 | monte alegre de minas
# Processing Record 49 of Set 15 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 15 | stryy
# City not found. Skipping...
# Processing Record 1 of Set 16 | port hardy
# Processing Record 2 of Set 16 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 16 | burica
# City not found. Skipping...
# Processing Record 4 of Set 16 | floro
# Processing Record 5 of Set 16 | tahta
# Processing Record 6 of Set 16 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 16 | lagoa
# Processing Record 8 of Set 16 | san policarpo
# Processing Record 9 of Set 16 | teneguiban
# City not found. Skipping...
# Processing Record 10 of Set 16 | torbay
# Processing Record 11 of Set 16 | taloda
# Processing Record 12 of Set 16 | xingcheng
# Processing Record 13 of Set 16 | san patricio
# Processing Record 14 of Set 16 | svetlyy
# Processing Record 15 of Set 16 | lebu
# Processing Record 16 of Set 16 | alvaraes
# Processing Record 17 of Set 16 | ende
# Processing Record 18 of Set 16 | piranhas
# Processing Record 19 of Set 16 | kibala
# Processing Record 20 of Set 16 | hamilton
# Processing Record 21 of Set 16 | le port
# Processing Record 22 of Set 16 | huarmey
# Processing Record 23 of Set 16 | port-gentil
# Processing Record 24 of Set 16 | plouzane
# Processing Record 25 of Set 16 | aksu
# Processing Record 26 of Set 16 | broken hill
# Processing Record 27 of Set 16 | udachnyy
# Processing Record 28 of Set 16 | necochea
# Processing Record 29 of Set 16 | ust-nera
# Processing Record 30 of Set 16 | dhana
# Processing Record 31 of Set 16 | balkanabat
# Processing Record 32 of Set 16 | chara
# Processing Record 33 of Set 16 | tarko-sale
# Processing Record 34 of Set 16 | warqla
# City not found. Skipping...
# Processing Record 35 of Set 16 | flinders
# Processing Record 36 of Set 16 | balabac
# Processing Record 37 of Set 16 | zhigansk
# Processing Record 38 of Set 16 | kismayo
# Processing Record 39 of Set 16 | bambous virieux
# Processing Record 40 of Set 16 | los llanos de aridane
# Processing Record 41 of Set 16 | makakilo city
# Processing Record 42 of Set 16 | natal
# Processing Record 43 of Set 16 | bandarbeyla
# Processing Record 44 of Set 16 | santa rita
# Processing Record 45 of Set 16 | pandan
# Processing Record 46 of Set 16 | filadelfia
# Processing Record 47 of Set 16 | saint george
# Processing Record 48 of Set 16 | ribeira grande
# Processing Record 49 of Set 16 | tondano
# Processing Record 50 of Set 16 | tamandare
# Processing Record 1 of Set 17 | margate
# Processing Record 2 of Set 17 | walvis bay
# Processing Record 3 of Set 17 | viedma
# Processing Record 4 of Set 17 | komsomolskiy
# Processing Record 5 of Set 17 | poya
# Processing Record 6 of Set 17 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 17 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 17 | vanimo
# Processing Record 9 of Set 17 | panzhihua
# Processing Record 10 of Set 17 | businga
# Processing Record 11 of Set 17 | tarakan
# Processing Record 12 of Set 17 | sisimiut
# Processing Record 13 of Set 17 | safford
# Processing Record 14 of Set 17 | tilichiki
# Processing Record 15 of Set 17 | caravelas
# Processing Record 16 of Set 17 | lhokseumawe
# Processing Record 17 of Set 17 | tracy
# Processing Record 18 of Set 17 | longyearbyen
# Processing Record 19 of Set 17 | narsaq
# Processing Record 20 of Set 17 | codrington
# Processing Record 21 of Set 17 | the pas
# Processing Record 22 of Set 17 | kyren
# Processing Record 23 of Set 17 | cabo san lucas
# Processing Record 24 of Set 17 | panaba
# Processing Record 25 of Set 17 | yakeshi
# Processing Record 26 of Set 17 | inuvik
# Processing Record 27 of Set 17 | pokaran
# Processing Record 28 of Set 17 | dom pedrito
# Processing Record 29 of Set 17 | kapuskasing
# Processing Record 30 of Set 17 | ondorhaan
# City not found. Skipping...
# Processing Record 31 of Set 17 | limbang
# Processing Record 32 of Set 17 | shimanovsk
# Processing Record 33 of Set 17 | mandurah
# Processing Record 34 of Set 17 | rungata
# City not found. Skipping...
# Processing Record 35 of Set 17 | birao
# Processing Record 36 of Set 17 | maniitsoq
# Processing Record 37 of Set 17 | namibe
# Processing Record 38 of Set 17 | durban
# Processing Record 39 of Set 17 | emba
# Processing Record 40 of Set 17 | victoria
# Processing Record 41 of Set 17 | haines junction
# Processing Record 42 of Set 17 | sabha
# Processing Record 43 of Set 17 | adrar
# Processing Record 44 of Set 17 | fare
# Processing Record 45 of Set 17 | mineral wells
# Processing Record 46 of Set 17 | lodja
# Processing Record 47 of Set 17 | watsa
# Processing Record 48 of Set 17 | faanui
# Processing Record 49 of Set 17 | rupert
# Processing Record 50 of Set 17 | cariati
# Processing Record 1 of Set 18 | sao joao da barra
# Processing Record 2 of Set 18 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 18 | ponta do sol
# Processing Record 4 of Set 18 | nenjiang
# Processing Record 5 of Set 18 | bur gabo
# City not found. Skipping...
# Processing Record 6 of Set 18 | shelburne
# Processing Record 7 of Set 18 | urumqi
# Processing Record 8 of Set 18 | dharmavaram
# Processing Record 9 of Set 18 | vetovo
# Processing Record 10 of Set 18 | ulaangom
# Processing Record 11 of Set 18 | mattawa
# Processing Record 12 of Set 18 | lugovoy
# Processing Record 13 of Set 18 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 18 | karpathos
# Processing Record 15 of Set 18 | chunoyar
# Processing Record 16 of Set 18 | chernyshevskiy
# Processing Record 17 of Set 18 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 18 | burkhala
# City not found. Skipping...
# Processing Record 19 of Set 18 | praxedis guerrero
# Processing Record 20 of Set 18 | morehead
# Processing Record 21 of Set 18 | luau
# City not found. Skipping...
# Processing Record 22 of Set 18 | zhuhai
# Processing Record 23 of Set 18 | bokspits
# City not found. Skipping...
# Processing Record 24 of Set 18 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 18 | saint-leu
# Processing Record 26 of Set 18 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 18 | bandraboua
# Processing Record 28 of Set 18 | souillac
# Processing Record 29 of Set 18 | tornio
# Processing Record 30 of Set 18 | monrovia
# Processing Record 31 of Set 18 | airai
# Processing Record 32 of Set 18 | palmer
# Processing Record 33 of Set 18 | englewood
# Processing Record 34 of Set 18 | portmarnock
# Processing Record 35 of Set 18 | gat
# Processing Record 36 of Set 18 | vostok
# Processing Record 37 of Set 18 | hit
# Processing Record 38 of Set 18 | obo
# Processing Record 39 of Set 18 | queanbeyan
# Processing Record 40 of Set 18 | yaan
# Processing Record 41 of Set 18 | thinadhoo
# Processing Record 42 of Set 18 | khonuu
# City not found. Skipping...
# Processing Record 43 of Set 18 | ust-omchug
# Processing Record 44 of Set 18 | bulungu
# Processing Record 45 of Set 18 | pisco
# Processing Record 46 of Set 18 | kaeo
# Processing Record 47 of Set 18 | rantepao
# Processing Record 48 of Set 18 | port victoria
# Processing Record 49 of Set 18 | akyab
# Processing Record 50 of Set 18 | baft
# Processing Record 1 of Set 19 | the valley
# Processing Record 2 of Set 19 | husavik
# Processing Record 3 of Set 19 | mount gambier
# Processing Record 4 of Set 19 | semporna
# Processing Record 5 of Set 19 | portland
# Processing Record 6 of Set 19 | peniche
# Processing Record 7 of Set 19 | saint-augustin
# Processing Record 8 of Set 19 | dryden
# Processing Record 9 of Set 19 | itarema
# Processing Record 10 of Set 19 | kimberley
# Processing Record 11 of Set 19 | grand gaube
# Processing Record 12 of Set 19 | chopda
# Processing Record 13 of Set 19 | vardo
# Processing Record 14 of Set 19 | moose factory
# Processing Record 15 of Set 19 | yuli
# Processing Record 16 of Set 19 | preston
# Processing Record 17 of Set 19 | hervey bay
# Processing Record 18 of Set 19 | dudinka
# Processing Record 19 of Set 19 | katsuura
# Processing Record 20 of Set 19 | nguiu
# City not found. Skipping...
# Processing Record 21 of Set 19 | domokos
# Processing Record 22 of Set 19 | moosomin
# Processing Record 23 of Set 19 | karamea
# City not found. Skipping...
# Processing Record 24 of Set 19 | fukue
# Processing Record 25 of Set 19 | praia da vitoria
# Processing Record 26 of Set 19 | vranov
# Processing Record 27 of Set 19 | san jose
# Processing Record 28 of Set 19 | taoudenni
# Processing Record 29 of Set 19 | richards bay
# Processing Record 30 of Set 19 | portobelo
# Processing Record 31 of Set 19 | ngukurr
# City not found. Skipping...
# Processing Record 32 of Set 19 | tateyama
# Processing Record 33 of Set 19 | moen
# Processing Record 34 of Set 19 | omboue
# Processing Record 35 of Set 19 | rawson
# Processing Record 36 of Set 19 | chagda
# City not found. Skipping...
# Processing Record 37 of Set 19 | ciras
# City not found. Skipping...
# Processing Record 38 of Set 19 | khandyga
# Processing Record 39 of Set 19 | sandwick
# Processing Record 40 of Set 19 | pemba
# Processing Record 41 of Set 19 | shieli
# Processing Record 42 of Set 19 | araguatins
# City not found. Skipping...
# Processing Record 43 of Set 19 | moorhead
# Processing Record 44 of Set 19 | olafsvik
# Processing Record 45 of Set 19 | farafangana
# Processing Record 46 of Set 19 | rincon
# Processing Record 47 of Set 19 | huilong
# Processing Record 48 of Set 19 | tarnogskiy gorodok
# Processing Record 49 of Set 19 | shaoxing
# Processing Record 50 of Set 19 | paita
# Processing Record 1 of Set 20 | orlik
# Processing Record 2 of Set 20 | marand
# Processing Record 3 of Set 20 | talnakh
# Processing Record 4 of Set 20 | bolivar
# Processing Record 5 of Set 20 | newport
# Processing Record 6 of Set 20 | ciudad bolivar
# Processing Record 7 of Set 20 | plotnikovo
# Processing Record 8 of Set 20 | ahipara
# Processing Record 9 of Set 20 | visnes
# Processing Record 10 of Set 20 | buin
# Processing Record 11 of Set 20 | aksarka
# Processing Record 12 of Set 20 | klerksdorp
# Processing Record 13 of Set 20 | beringovskiy
# Processing Record 14 of Set 20 | maridi
# Processing Record 15 of Set 20 | shenjiamen
# Processing Record 16 of Set 20 | cockburn town
# Processing Record 17 of Set 20 | kungurtug
# Processing Record 18 of Set 20 | baisha
# Processing Record 19 of Set 20 | plettenberg bay
# Processing Record 20 of Set 20 | jojoima
# Processing Record 21 of Set 20 | kulu
# Processing Record 22 of Set 20 | aransas pass
# Processing Record 23 of Set 20 | flekkefjord
# Processing Record 24 of Set 20 | coburg
# Processing Record 25 of Set 20 | mezen
# Processing Record 26 of Set 20 | arlit
# Processing Record 27 of Set 20 | bonavista
# Processing Record 28 of Set 20 | murray bridge
# Processing Record 29 of Set 20 | awjilah
# Processing Record 30 of Set 20 | oktyabrskiy
# Processing Record 31 of Set 20 | kununurra
# Processing Record 32 of Set 20 | toktogul
# Processing Record 33 of Set 20 | karachi
# Processing Record 34 of Set 20 | colac
# Processing Record 35 of Set 20 | srandakan
# Processing Record 36 of Set 20 | buala
# Processing Record 37 of Set 20 | cap malheureux
# Processing Record 38 of Set 20 | mao
# Processing Record 39 of Set 20 | saldanha
# Processing Record 40 of Set 20 | eldorado
# Processing Record 41 of Set 20 | bandar
# Processing Record 42 of Set 20 | noumea
# Processing Record 43 of Set 20 | ayan
# Processing Record 44 of Set 20 | samalaeulu
# City not found. Skipping...
# Processing Record 45 of Set 20 | linjiang
# Processing Record 46 of Set 20 | rudiskes
# Processing Record 47 of Set 20 | coihaique
# Processing Record 48 of Set 20 | beya
# Processing Record 49 of Set 20 | egvekinot
# Processing Record 50 of Set 20 | ostrovnoy
# Processing Record 1 of Set 21 | pemangkat
# Processing Record 2 of Set 21 | wucheng
# Processing Record 3 of Set 21 | port macquarie
# Processing Record 4 of Set 21 | lata
# Processing Record 5 of Set 21 | sindor
# Processing Record 6 of Set 21 | hami
# Processing Record 7 of Set 21 | teguise
# Processing Record 8 of Set 21 | evensk
# Processing Record 9 of Set 21 | bathsheba
# Processing Record 10 of Set 21 | dossor
# Processing Record 11 of Set 21 | sorland
# Processing Record 12 of Set 21 | yining
# Processing Record 13 of Set 21 | cachira
# Processing Record 14 of Set 21 | luganville
# Processing Record 15 of Set 21 | kijang
# Processing Record 16 of Set 21 | murgab
# Processing Record 17 of Set 21 | zolotinka
# City not found. Skipping...
# Processing Record 18 of Set 21 | lorengau
# Processing Record 19 of Set 21 | fort abbas
# Processing Record 20 of Set 21 | suba
# Processing Record 21 of Set 21 | ungheni
# Processing Record 22 of Set 21 | tiksi
# Processing Record 23 of Set 21 | douglas
# Processing Record 24 of Set 21 | ayagoz
# Processing Record 25 of Set 21 | laguna
# Processing Record 26 of Set 21 | kruisfontein
# Processing Record 27 of Set 21 | sitka
# Processing Record 28 of Set 21 | waingapu
# Processing Record 29 of Set 21 | wheeling
# Processing Record 30 of Set 21 | kadi
# Processing Record 31 of Set 21 | bengkulu
# Processing Record 32 of Set 21 | el alto
# Processing Record 33 of Set 21 | san quintin
# Processing Record 34 of Set 21 | morro bay
# Processing Record 35 of Set 21 | pau dos ferros
# Processing Record 36 of Set 21 | kahului
# Processing Record 37 of Set 21 | hirara
# Processing Record 38 of Set 21 | alofi
# Processing Record 39 of Set 21 | wakkanai
# Processing Record 40 of Set 21 | avera
# Processing Record 41 of Set 21 | lakatoro
# Processing Record 42 of Set 21 | soltepec
# Processing Record 43 of Set 21 | fortuna
# Processing Record 44 of Set 21 | meadow lake
# Processing Record 45 of Set 21 | tarauaca
# Processing Record 46 of Set 21 | izumo
# Processing Record 47 of Set 21 | comodoro rivadavia
# Processing Record 48 of Set 21 | alekseyevsk
# Processing Record 49 of Set 21 | curup
# Processing Record 50 of Set 21 | turmalina
# Processing Record 1 of Set 22 | umred
# Processing Record 2 of Set 22 | ankang
# Processing Record 3 of Set 22 | outlook
# Processing Record 4 of Set 22 | kuopio
# Processing Record 5 of Set 22 | kalaleh
# Processing Record 6 of Set 22 | simao
# Processing Record 7 of Set 22 | saint-alexandre
# Processing Record 8 of Set 22 | seguela
# Processing Record 9 of Set 22 | wajima
# City not found. Skipping...
# Processing Record 10 of Set 22 | ajdabiya
# Processing Record 11 of Set 22 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 12 of Set 22 | praia
# Processing Record 13 of Set 22 | kadykchan
# City not found. Skipping...
# Processing Record 14 of Set 22 | fuchu
# Processing Record 15 of Set 22 | plainview
# Processing Record 16 of Set 22 | dunga bunga
# Processing Record 17 of Set 22 | vao
# Processing Record 18 of Set 22 | saint-pierre
# Processing Record 19 of Set 22 | sharjah
# Processing Record 20 of Set 22 | tautira
# Processing Record 21 of Set 22 | moyale
# Processing Record 22 of Set 22 | kushima
# Processing Record 23 of Set 22 | vila do maio
# Processing Record 24 of Set 22 | paradwip
# City not found. Skipping...
# Processing Record 25 of Set 22 | nouadhibou
# Processing Record 26 of Set 22 | slave lake
# Processing Record 27 of Set 22 | sorvag
# City not found. Skipping...
# Processing Record 28 of Set 22 | cayenne
# Processing Record 29 of Set 22 | constitucion
# Processing Record 30 of Set 22 | ballina
# Processing Record 31 of Set 22 | akalkot
# Processing Record 32 of Set 22 | dukat
# Processing Record 33 of Set 22 | zheleznodorozhnyy
# Processing Record 34 of Set 22 | gushikawa
# Processing Record 35 of Set 22 | campbell river
# Processing Record 36 of Set 22 | charters towers
# Processing Record 37 of Set 22 | selimpasa
# Processing Record 38 of Set 22 | verkhnevilyuysk
# Processing Record 39 of Set 22 | ternate
# Processing Record 40 of Set 22 | sampit
# Processing Record 41 of Set 22 | vestmannaeyjar
# Processing Record 42 of Set 22 | satana
# Processing Record 43 of Set 22 | henties bay
# Processing Record 44 of Set 22 | narasaraopet
# Processing Record 45 of Set 22 | trairi
# Processing Record 46 of Set 22 | moengo
# Processing Record 47 of Set 22 | manzil salim
# Processing Record 48 of Set 22 | uberlandia
# Processing Record 49 of Set 22 | artyom
# Processing Record 50 of Set 22 | afua
# Processing Record 1 of Set 23 | ust-tsilma
# Processing Record 2 of Set 23 | esso
# Processing Record 3 of Set 23 | guiratinga
# Processing Record 4 of Set 23 | takoradi
# Processing Record 5 of Set 23 | san jeronimo
# Processing Record 6 of Set 23 | batemans bay
# Processing Record 7 of Set 23 | ghanzi
# Processing Record 8 of Set 23 | madaoua
# Processing Record 9 of Set 23 | bethanien
# Processing Record 10 of Set 23 | balasheyka
# Processing Record 11 of Set 23 | shimoda
# Processing Record 12 of Set 23 | medea

# %%
len(city_data)

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()

# %%
new_column_order = ["City",'Country','Date','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed']
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label='City_ID')

# %%
#extract relevant fields from dataframe for plotting 
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]
import time 
today = time.time()
today

# %%
today = time.strftime("%x")
today

# %%
#add time.strftime("%x") to our plt.title() function in our scatter plot.
import time 
plt.scatter(lats,
           max_temps,
           edgecolor = 'black', linewidth = 1,
            marker = 'o',alpha = 0.8, label="Cities")
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("weather_data/Fig1.png")
plt.show()

# %%
#change the yaxis to humidity 
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
#latitude vs. cloudiness 
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
#latitude vs. wind speed. 
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")
# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
from scipy.stats import linregress
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    regress_values = x_values * slope  + intercept 
    line_eq = 'y=' + str(round(slope,2)) + 'x+'+ str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
#apply loc() in city_data_df to create hemisphere datafram 
index13 = city_data_df.loc[13]
index13

# %%
#or filter the latitude > 0 for north hemisphere 
city_data_df['Lat']>=0

# %%
#use loc[condition lat>=0] to filter south and north hemisphere 
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']
# Call the function.
plot_linear_regression(x_values, y_values, 
                       'Linear Regression on the Northern Hemisphere for Maximum Temperature', 'Max Temp',(10,40))
#change the text coordinates until see the equation

# %%
# linear regression on southern hemi 
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']
plot_linear_regression(x_values, y_values,'Linear Regression on the Southern Hemisphere for Maximum Temperature',
                      'Max Temp', (-50,90))

# %%
#linear regression of northern hemi lat and humidity 
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']
plot_linear_regression(x_values, y_values, 'Linear Regression on Northern Hemisphere for % Humidity',
                      '% Humidity', (40,10))

# %%
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']
plot_linear_regression(x_values, y_values, 'Linear Regression on Southern Hemisphere for % Humidity',
                      '% Humidity', (-50,15))

# %%
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']
plot_linear_regression(x_values, y_values, 'Linear Regression on Northern Hemisphere for % Cloudiness',
                      '% Cloudiness', (40,10))

# %%
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']
plot_linear_regression(x_values, y_values, 'Linear Regression on Southern Hemisphere for % Cloudiness',
                      '% Cloudiness', (-50,15))

# %%
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']
plot_linear_regression(x_values, y_values, 'Linear Regression on Northern Hemisphere for Wind Speed',
                      'Wind Speed', (40,10))

# %%
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']
plot_linear_regression(x_values, y_values, 'Linear Regression on Southern Hemisphere for Wind Speed',
                      'Wind Speed', (-50,15))
